# %% [markdown]
# <a href="https://colab.research.google.com/github/Filimize/image_segmentation/blob/main/SEGMENTATION_MODEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## IMPORT DATA

# %%
# !gdown 1-0BOPoCFc1ebtxp643lqmsutfVGRtzLL
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-0BOPoCFc1ebtxp643lqmsutfVGRtzLL
# To: /content/one-slide_1.zip
# 100% 647M/647M [00:09<00:00, 67.3MB/s]

# %%
# !unzip /content/one-slide_1.zip
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
#   inflating: images/ID00051637202185848464638_38.jpg
#   inflating: images/ID00329637202285906759848_77.jpg
#   inflating: images/ID00414637202310318891556_124.jpg
#   inflating: images/ID00131637202220424084844_96.jpg
#   inflating: images/ID00400637202305055099402_4.jpg
#   inflating: images/ID00381637202299644114027_241.jpg
#   inflating: images/ID00414637202310318891556_212.jpg
#   inflating: images/ID00411637202309374271828_211.jpg
#   inflating: images/ID00015637202177877247924_158.jpg
#   inflating: images/ID00122637202216437668965_14.jpg
#   inflating: images/ID00192637202245493238298_116.jpg
#   inflating: images/ID00009637202177434476278_363.jpg
#   inflating: images/ID00381637202299644114027_61.jpg
#   inflating: images/ID00140637202231728595149_72.jpg
#   inflating: images/ID00218637202258156844710_39.jpg
#   inflating: images/ID00129637202219868188000_20.jpg
#   inflating: images/ID00110637202210673668310_204.jpg
#   inflating: images/ID00273637202271319294586_1.jpg
#   inflating: images/ID00009637202177434476278_108.jpg
#   inflating: images/ID00123637202217151272140_121.jpg
#   inflating: images/ID00111637202210956877205_26.jpg
#   inflating: images/ID00167637202237397919352_22.jpg
#   inflating: images/ID00089637202204675567570_14.jpg
#   inflating: images/ID00035637202182204917484_13.jpg
#   inflating: images/ID00213637202257692916109_242.jpg
#   inflating: images/ID00381637202299644114027_45.jpg
#   inflating: images/ID00285637202278913507108_2.jpg
#   inflating: images/ID00168637202237852027833_6.jpg
#   inflating: images/ID00169637202238024117706_50.jpg
#   inflating: images/ID00012637202177665765362_7.jpg
#   inflating: images/ID00414637202310318891556_85.jpg
#   inflating: images/ID00383637202300493233675_3.jpg
#   inflating: images/ID00192637202245493238298_73.jpg
#   inflating: images/ID00329637202285906759848_27.jpg
#   inflating: images/ID00213637202257692916109_108.jpg
#   inflating: images/ID00111637202210956877205_211.jpg
#   inflating: images/ID00131637202220424084844_92.jpg
#   inflating: images/ID00186637202242472088675_357.jpg
#   inflating: images/ID00235637202261451839085_279.jpg
#   inflating: images/ID00335637202286784464927_24.jpg
#   inflating: images/ID00219637202258203123958_253.jpg
#   inflating: images/ID00423637202312137826377_167.jpg
#   inflating: images/ID00358637202295388077032_310.jpg
#   inflating: images/ID00360637202295712204040_81.jpg
#   inflating: images/ID00109637202210454292264_41.jpg
#   inflating: images/ID00299637202280383305867_46.jpg
#   inflating: images/ID00122637202216437668965_24.jpg
#   inflating: images/ID00090637202204766623410_21.jpg
#   inflating: images/ID00275637202271440119890_156.jpg
#   inflating: images/ID00275637202271440119890_125.jpg
#   inflating: images/ID00168637202237852027833_251.jpg
#   inflating: images/ID00035637202182204917484_470.jpg
#   inflating: images/ID00035637202182204917484_541.jpg
#   inflating: images/ID00358637202295388077032_106.jpg
#   inflating: images/ID00426637202313170790466_197.jpg
#   inflating: images/ID00035637202182204917484_264.jpg
#   inflating: images/ID00167637202237397919352_175.jpg
#   inflating: images/ID00104637202208063407045_350.jpg
#   inflating: images/ID00186637202242472088675_307.jpg
#   inflating: images/ID00186637202242472088675_47.jpg
#   inflating: images/ID00219637202258203123958_204.jpg
#   inflating: images/ID00241637202264294508775_25.jpg
#   inflating: images/ID00323637202285211956970_246.jpg
#   inflating: images/ID00168637202237852027833_221.jpg
#   inflating: images/ID00027637202179689871102_181.jpg
#   inflating: images/ID00381637202299644114027_394.jpg
#   inflating: images/ID00210637202257228694086_13.jpg
#   inflating: images/ID00423637202312137826377_55.jpg
#   inflating: images/ID00219637202258203123958_167.jpg
#   inflating: images/ID00109637202210454292264_247.jpg
#   inflating: images/ID00075637202198610425520_248.jpg
#   inflating: images/ID00035637202182204917484_100.jpg
#   inflating: images/ID00407637202308788732304_36.jpg
#   inflating: images/ID00426637202313170790466_148.jpg
#   inflating: images/ID00275637202271440119890_242.jpg
#   inflating: images/ID00213637202257692916109_194.jpg
#   inflating: images/ID00426637202313170790466_169.jpg
#   inflating: images/ID00009637202177434476278_359.jpg
#   inflating: images/ID00329637202285906759848_214.jpg
#   inflating: images/ID00381637202299644114027_81.jpg
#   inflating: images/ID00167637202237397919352_148.jpg
#   inflating: images/ID00009637202177434476278_45.jpg
#   inflating: images/ID00186637202242472088675_198.jpg
#   inflating: images/ID00398637202303897337979_41.jpg
#   inflating: images/ID00082637202201836229724_29.jpg
#   inflating: images/ID00104637202208063407045_402.jpg
#   inflating: images/ID00323637202285211956970_153.jpg
#   inflating: images/ID00170637202238079193844_50.jpg
#   inflating: images/ID00249637202266730854017_288.jpg
#   inflating: images/ID00360637202295712204040_54.jpg
#   inflating: images/ID00102637202206574119190_28.jpg
#   inflating: images/ID00060637202187965290703_119.jpg
#   inflating: images/ID00267637202270790561585_48.jpg
#   inflating: images/ID00210637202257228694086_56.jpg
#   inflating: images/ID00285637202278913507108_23.jpg
#   inflating: images/ID00355637202295106567614_6.jpg
#   inflating: images/ID00104637202208063407045_365.jpg
#   inflating: images/ID00111637202210956877205_65.jpg
#   inflating: images/ID00082637202201836229724_39.jpg
#   inflating: images/ID00035637202182204917484_185.jpg
#   inflating: images/ID00358637202295388077032_124.jpg
#   inflating: images/ID00131637202220424084844_20.jpg
#   inflating: images/ID00035637202182204917484_272.jpg
#   inflating: images/ID00235637202261451839085_158.jpg
#   inflating: images/ID00199637202248141386743_59.jpg
#   inflating: images/ID00167637202237397919352_107.jpg
#   inflating: images/ID00370637202296737666151_89.jpg
#   inflating: images/ID00335637202286784464927_2.jpg
#   inflating: images/ID00060637202187965290703_221.jpg
#   inflating: images/ID00241637202264294508775_208.jpg
#   inflating: images/ID00344637202287684217717_171.jpg
#   inflating: images/ID00241637202264294508775_200.jpg
#   inflating: images/ID00365637202296085035729_53.jpg
#   inflating: images/ID00411637202309374271828_251.jpg
#   inflating: images/ID00219637202258203123958_82.jpg
#   inflating: images/ID00235637202261451839085_80.jpg
#   inflating: images/ID00104637202208063407045_111.jpg
#   inflating: images/ID00367637202296290303449_193.jpg
#   inflating: images/ID00104637202208063407045_449.jpg
#   inflating: images/ID00329637202285906759848_254.jpg
#   inflating: images/ID00329637202285906759848_249.jpg
#   inflating: images/ID00218637202258156844710_33.jpg
#   inflating: images/ID00076637202199015035026_45.jpg
#   inflating: images/ID00032637202181710233084_51.jpg
#   inflating: images/ID00032637202181710233084_134.jpg
#   inflating: images/ID00111637202210956877205_151.jpg
#   inflating: images/ID00167637202237397919352_132.jpg
#   inflating: images/ID00104637202208063407045_95.jpg
#   inflating: images/ID00381637202299644114027_333.jpg
#   inflating: images/ID00104637202208063407045_206.jpg
#   inflating: images/ID00104637202208063407045_99.jpg
#   inflating: images/ID00061637202188184085559_6.jpg
#   inflating: images/ID00219637202258203123958_185.jpg
#   inflating: images/ID00051637202185848464638_37.jpg
#   inflating: images/ID00186637202242472088675_25.jpg
#   inflating: images/ID00423637202312137826377_240.jpg
#   inflating: images/ID00273637202271319294586_54.jpg
#   inflating: images/ID00426637202313170790466_77.jpg
#   inflating: images/ID00035637202182204917484_159.jpg
#   inflating: images/ID00207637202252526380974_41.jpg
#   inflating: images/ID00331637202286306023714_18.jpg
#   inflating: images/ID00219637202258203123958_325.jpg
#   inflating: images/ID00035637202182204917484_307.jpg
#   inflating: images/ID00235637202261451839085_207.jpg
#   inflating: images/ID00249637202266730854017_227.jpg
#   inflating: images/ID00275637202271440119890_29.jpg
#   inflating: images/ID00073637202198167792918_279.jpg
#   inflating: images/ID00035637202182204917484_467.jpg
#   inflating: images/ID00290637202279304677843_56.jpg
#   inflating: images/ID00219637202258203123958_240.jpg
#   inflating: images/ID00210637202257228694086_141.jpg
#   inflating: images/ID00010637202177584971671_29.jpg
#   inflating: images/ID00407637202308788732304_30.jpg
#   inflating: images/ID00105637202208831864134_24.jpg
#   inflating: images/ID00197637202246865691526_23.jpg
#   inflating: images/ID00210637202257228694086_87.jpg
#   inflating: images/ID00076637202199015035026_16.jpg
#   inflating: images/ID00104637202208063407045_363.jpg
#   inflating: images/ID00426637202313170790466_56.jpg
#   inflating: images/ID00225637202259339837603_27.jpg
#   inflating: images/ID00417637202310901214011_33.jpg
#   inflating: images/ID00192637202245493238298_35.jpg
#   inflating: images/ID00322637202284842245491_87.jpg
#   inflating: images/ID00076637202199015035026_39.jpg
#   inflating: images/ID00104637202208063407045_202.jpg
#   inflating: images/ID00075637202198610425520_97.jpg
#   inflating: images/ID00027637202179689871102_18.jpg
#   inflating: images/ID00290637202279304677843_231.jpg
#   inflating: images/ID00104637202208063407045_413.jpg
#   inflating: images/ID00104637202208063407045_32.jpg
#   inflating: images/ID00355637202295106567614_28.jpg
#   inflating: images/ID00015637202177877247924_215.jpg
#   inflating: images/ID00123637202217151272140_215.jpg
#   inflating: images/ID00426637202313170790466_170.jpg
#   inflating: images/ID00322637202284842245491_45.jpg
#   inflating: images/ID00235637202261451839085_113.jpg
#   inflating: images/ID00051637202185848464638_79.jpg
#   inflating: images/ID00358637202295388077032_257.jpg
#   inflating: images/ID00139637202231703564336_31.jpg
#   inflating: images/ID00075637202198610425520_260.jpg
#   inflating: images/ID00299637202280383305867_9.jpg
#   inflating: images/ID00184637202242062969203_4.jpg
#   inflating: images/ID00035637202182204917484_455.jpg
#   inflating: images/ID00305637202281772703145_4.jpg
#   inflating: images/ID00009637202177434476278_183.jpg
#   inflating: images/ID00323637202285211956970_93.jpg
#   inflating: images/ID00225637202259339837603_102.jpg
#   inflating: images/ID00285637202278913507108_22.jpg
#   inflating: images/ID00076637202199015035026_56.jpg
#   inflating: images/ID00299637202280383305867_28.jpg
#   inflating: images/ID00414637202310318891556_151.jpg
#   inflating: images/ID00299637202280383305867_29.jpg
#   inflating: images/ID00027637202179689871102_301.jpg
#   inflating: images/ID00027637202179689871102_268.jpg
#   inflating: images/ID00219637202258203123958_348.jpg
#   inflating: images/ID00123637202217151272140_6.jpg
#   inflating: images/ID00219637202258203123958_214.jpg
#   inflating: images/ID00323637202285211956970_12.jpg
#   inflating: images/ID00104637202208063407045_236.jpg
#   inflating: images/ID00109637202210454292264_72.jpg
#   inflating: images/ID00323637202285211956970_122.jpg
#   inflating: images/ID00235637202261451839085_174.jpg
#   inflating: images/ID00355637202295106567614_26.jpg
#   inflating: images/ID00370637202296737666151_102.jpg
#   inflating: images/ID00392637202302319160044_43.jpg
#   inflating: images/ID00329637202285906759848_39.jpg
#   inflating: images/ID00213637202257692916109_97.jpg
#   inflating: images/ID00249637202266730854017_117.jpg
#   inflating: images/ID00104637202208063407045_436.jpg
#   inflating: images/ID00032637202181710233084_189.jpg
#   inflating: images/ID00323637202285211956970_225.jpg
#   inflating: images/ID00414637202310318891556_165.jpg
#   inflating: images/ID00423637202312137826377_127.jpg
#   inflating: images/ID00196637202246668775836_18.jpg
#   inflating: images/ID00411637202309374271828_188.jpg
#   inflating: images/ID00025637202179541264076_17.jpg
#   inflating: images/ID00426637202313170790466_166.jpg
#   inflating: images/ID00197637202246865691526_27.jpg
#   inflating: images/ID00109637202210454292264_39.jpg
#   inflating: images/ID00275637202271440119890_194.jpg
#   inflating: images/ID00367637202296290303449_99.jpg
#   inflating: images/ID00225637202259339837603_162.jpg
#   inflating: images/ID00219637202258203123958_368.jpg
#   inflating: images/ID00167637202237397919352_114.jpg
#   inflating: images/ID00400637202305055099402_197.jpg
#   inflating: images/ID00423637202312137826377_70.jpg
#   inflating: images/ID00111637202210956877205_273.jpg
#   inflating: images/ID00035637202182204917484_84.jpg
#   inflating: images/ID00331637202286306023714_62.jpg
#   inflating: images/ID00355637202295106567614_7.jpg
#   inflating: images/ID00027637202179689871102_221.jpg
#   inflating: images/ID00279637202272164826258_24.jpg
#   inflating: images/ID00027637202179689871102_142.jpg
#   inflating: images/ID00370637202296737666151_209.jpg
#   inflating: images/ID00186637202242472088675_405.jpg
#   inflating: images/ID00073637202198167792918_2.jpg
#   inflating: images/ID00358637202295388077032_182.jpg
#   inflating: images/ID00032637202181710233084_171.jpg
#   inflating: images/ID00360637202295712204040_39.jpg
#   inflating: images/ID00219637202258203123958_10.jpg
#   inflating: images/ID00168637202237852027833_65.jpg
#   inflating: images/ID00140637202231728595149_133.jpg
#   inflating: images/ID00219637202258203123958_171.jpg
#   inflating: images/ID00102637202206574119190_66.jpg
#   inflating: images/ID00104637202208063407045_57.jpg
#   inflating: images/ID00126637202218610655908_7.jpg
#   inflating: images/ID00009637202177434476278_345.jpg
#   inflating: images/ID00381637202299644114027_20.jpg
#   inflating: images/ID00060637202187965290703_182.jpg
#   inflating: images/ID00275637202271440119890_226.jpg
#   inflating: images/ID00077637202199102000916_84.jpg
#   inflating: images/ID00249637202266730854017_290.jpg
#   inflating: images/ID00186637202242472088675_350.jpg
#   inflating: images/ID00235637202261451839085_5.jpg
#   inflating: images/ID00381637202299644114027_125.jpg
#   inflating: images/ID00073637202198167792918_149.jpg
#   inflating: images/ID00219637202258203123958_279.jpg
#   inflating: images/ID00210637202257228694086_93.jpg
#   inflating: images/ID00009637202177434476278_71.jpg
#   inflating: images/ID00015637202177877247924_3.jpg
#   inflating: images/ID00367637202296290303449_221.jpg
#   inflating: images/ID00104637202208063407045_49.jpg
#   inflating: images/ID00009637202177434476278_18.jpg
#   inflating: images/ID00015637202177877247924_50.jpg
#   inflating: images/ID00060637202187965290703_113.jpg
#   inflating: images/ID00110637202210673668310_61.jpg
#   inflating: images/ID00344637202287684217717_6.jpg
#   inflating: images/ID00075637202198610425520_259.jpg
#   inflating: images/ID00322637202284842245491_26.jpg
#   inflating: images/ID00105637202208831864134_6.jpg
#   inflating: images/ID00423637202312137826377_172.jpg
#   inflating: images/ID00358637202295388077032_78.jpg
#   inflating: images/ID00168637202237852027833_54.jpg
#   inflating: images/ID00249637202266730854017_120.jpg
#   inflating: images/ID00229637202260254240583_10.jpg
#   inflating: images/ID00073637202198167792918_299.jpg
#   inflating: images/ID00249637202266730854017_2.jpg
#   inflating: images/ID00423637202312137826377_84.jpg
#   inflating: images/ID00061637202188184085559_50.jpg
#   inflating: images/ID00104637202208063407045_161.jpg
#   inflating: images/ID00109637202210454292264_105.jpg
#   inflating: images/ID00035637202182204917484_556.jpg
#   inflating: images/ID00161637202235731948764_19.jpg
#   inflating: images/ID00015637202177877247924_165.jpg
#   inflating: images/ID00068637202190879923934_99.jpg
#   inflating: images/ID00400637202305055099402_153.jpg
#   inflating: images/ID00170637202238079193844_125.jpg
#   inflating: images/ID00199637202248141386743_48.jpg
#   inflating: images/ID00047637202184938901501_48.jpg
#   inflating: images/ID00009637202177434476278_306.jpg
#   inflating: images/ID00032637202181710233084_46.jpg
#   inflating: images/ID00367637202296290303449_167.jpg
#   inflating: images/ID00111637202210956877205_139.jpg
#   inflating: images/ID00102637202206574119190_10.jpg
#   inflating: images/ID00426637202313170790466_33.jpg
#   inflating: images/ID00109637202210454292264_49.jpg
#   inflating: images/ID00167637202237397919352_182.jpg
#   inflating: images/ID00331637202286306023714_6.jpg
#   inflating: images/ID00047637202184938901501_47.jpg
#   inflating: images/ID00015637202177877247924_120.jpg
#   inflating: images/ID00060637202187965290703_141.jpg
#   inflating: images/ID00027637202179689871102_105.jpg
#   inflating: images/ID00273637202271319294586_60.jpg
#   inflating: images/ID00073637202198167792918_100.jpg
#   inflating: images/ID00192637202245493238298_59.jpg
#   inflating: images/ID00125637202218590429387_19.jpg
#   inflating: images/ID00110637202210673668310_29.jpg
#   inflating: images/ID00035637202182204917484_510.jpg
#   inflating: images/ID00331637202286306023714_47.jpg
#   inflating: images/ID00275637202271440119890_2.jpg
#   inflating: images/ID00061637202188184085559_133.jpg
#   inflating: images/ID00186637202242472088675_129.jpg
#   inflating: images/ID00329637202285906759848_124.jpg
#   inflating: images/ID00421637202311550012437_9.jpg
#   inflating: images/ID00075637202198610425520_308.jpg
#   inflating: images/ID00358637202295388077032_61.jpg
#   inflating: images/ID00009637202177434476278_196.jpg
#   inflating: images/ID00411637202309374271828_191.jpg
#   inflating: images/ID00421637202311550012437_12.jpg
#   inflating: images/ID00061637202188184085559_153.jpg
#   inflating: images/ID00009637202177434476278_25.jpg
#   inflating: images/ID00102637202206574119190_187.jpg
#   inflating: images/ID00170637202238079193844_49.jpg
#   inflating: images/ID00102637202206574119190_179.jpg
#   inflating: images/ID00110637202210673668310_202.jpg
#   inflating: images/ID00047637202184938901501_20.jpg
#   inflating: images/ID00290637202279304677843_93.jpg
#   inflating: images/ID00110637202210673668310_163.jpg
#   inflating: images/ID00170637202238079193844_16.jpg
#   inflating: images/ID00123637202217151272140_51.jpg
#   inflating: images/ID00241637202264294508775_65.jpg
#   inflating: images/ID00032637202181710233084_117.jpg
#   inflating: images/ID00131637202220424084844_161.jpg
#   inflating: images/ID00015637202177877247924_19.jpg
#   inflating: images/ID00423637202312137826377_132.jpg
#   inflating: images/ID00213637202257692916109_104.jpg
#   inflating: images/ID00082637202201836229724_264.jpg
#   inflating: images/ID00355637202295106567614_27.jpg
#   inflating: images/ID00267637202270790561585_8.jpg
#   inflating: images/ID00241637202264294508775_232.jpg
#   inflating: images/ID00131637202220424084844_5.jpg
#   inflating: images/ID00298637202280361773446_8.jpg
#   inflating: images/ID00426637202313170790466_226.jpg
#   inflating: images/ID00358637202295388077032_88.jpg
#   inflating: images/ID00015637202177877247924_183.jpg
#   inflating: images/ID00235637202261451839085_119.jpg
#   inflating: images/ID00381637202299644114027_280.jpg
#   inflating: images/ID00323637202285211956970_105.jpg
#   inflating: images/ID00027637202179689871102_139.jpg
#   inflating: images/ID00139637202231703564336_28.jpg
#   inflating: images/ID00060637202187965290703_10.jpg
#   inflating: images/ID00167637202237397919352_196.jpg
#   inflating: images/ID00167637202237397919352_34.jpg
#   inflating: images/ID00235637202261451839085_31.jpg
#   inflating: images/ID00331637202286306023714_27.jpg
#   inflating: images/ID00249637202266730854017_274.jpg
#   inflating: images/ID00076637202199015035026_2.jpg
#   inflating: images/ID00358637202295388077032_262.jpg
#   inflating: images/ID00111637202210956877205_90.jpg
#   inflating: images/ID00009637202177434476278_42.jpg
#   inflating: images/ID00225637202259339837603_90.jpg
#   inflating: images/ID00267637202270790561585_53.jpg
#   inflating: images/ID00009637202177434476278_334.jpg
#   inflating: images/ID00219637202258203123958_305.jpg
#   inflating: images/ID00370637202296737666151_201.jpg
#   inflating: images/ID00275637202271440119890_68.jpg
#   inflating: images/ID00027637202179689871102_228.jpg
#   inflating: images/ID00322637202284842245491_67.jpg
#   inflating: images/ID00073637202198167792918_10.jpg
#   inflating: images/ID00104637202208063407045_147.jpg
#   inflating: images/ID00213637202257692916109_245.jpg
#   inflating: images/ID00051637202185848464638_103.jpg
#   inflating: images/ID00407637202308788732304_47.jpg
#   inflating: images/ID00009637202177434476278_293.jpg
#   inflating: images/ID00075637202198610425520_239.jpg
#   inflating: images/ID00170637202238079193844_115.jpg
#   inflating: images/ID00167637202237397919352_30.jpg
#   inflating: images/ID00076637202199015035026_32.jpg
#   inflating: images/ID00105637202208831864134_3.jpg
#   inflating: images/ID00019637202178323708467_18.jpg
#   inflating: images/ID00102637202206574119190_69.jpg
#   inflating: images/ID00235637202261451839085_196.jpg
#   inflating: images/ID00110637202210673668310_66.jpg
#   inflating: images/ID00186637202242472088675_121.jpg
#   inflating: images/ID00027637202179689871102_133.jpg
#   inflating: images/ID00186637202242472088675_192.jpg
#   inflating: images/ID00032637202181710233084_82.jpg
#   inflating: images/ID00082637202201836229724_101.jpg
#   inflating: images/ID00249637202266730854017_298.jpg
#   inflating: images/ID00417637202310901214011_17.jpg
#   inflating: images/ID00090637202204766623410_67.jpg
#   inflating: images/ID00392637202302319160044_9.jpg
#   inflating: images/ID00235637202261451839085_220.jpg
#   inflating: images/ID00400637202305055099402_167.jpg
#   inflating: images/ID00009637202177434476278_37.jpg
#   inflating: images/ID00381637202299644114027_124.jpg
#   inflating: images/ID00009637202177434476278_280.jpg
#   inflating: images/ID00219637202258203123958_39.jpg
#   inflating: images/ID00170637202238079193844_122.jpg
#   inflating: images/ID00213637202257692916109_248.jpg
#   inflating: images/ID00213637202257692916109_232.jpg
#   inflating: images/ID00102637202206574119190_110.jpg
#   inflating: images/ID00411637202309374271828_93.jpg
#   inflating: images/ID00267637202270790561585_33.jpg
#   inflating: images/ID00073637202198167792918_223.jpg
#   inflating: images/ID00129637202219868188000_16.jpg
#   inflating: images/ID00123637202217151272140_16.jpg
#   inflating: images/ID00104637202208063407045_90.jpg
#   inflating: images/ID00073637202198167792918_271.jpg
#   inflating: images/ID00014637202177757139317_14.jpg
#   inflating: images/ID00417637202310901214011_44.jpg
#   inflating: images/ID00322637202284842245491_27.jpg
#   inflating: images/ID00290637202279304677843_218.jpg
#   inflating: images/ID00170637202238079193844_67.jpg
#   inflating: images/ID00186637202242472088675_362.jpg
#   inflating: images/ID00010637202177584971671_52.jpg
#   inflating: images/ID00104637202208063407045_459.jpg
#   inflating: images/ID00077637202199102000916_18.jpg
#   inflating: images/ID00288637202279148973731_20.jpg
#   inflating: images/ID00167637202237397919352_86.jpg
#   inflating: images/ID00110637202210673668310_83.jpg
#   inflating: images/ID00035637202182204917484_485.jpg
#   inflating: images/ID00360637202295712204040_214.jpg
#   inflating: images/ID00168637202237852027833_245.jpg
#   inflating: images/ID00192637202245493238298_241.jpg
#   inflating: images/ID00186637202242472088675_31.jpg
#   inflating: images/ID00111637202210956877205_194.jpg
#   inflating: images/ID00027637202179689871102_84.jpg
#   inflating: images/ID00075637202198610425520_122.jpg
#   inflating: images/ID00235637202261451839085_100.jpg
#   inflating: images/ID00131637202220424084844_82.jpg
#   inflating: images/ID00299637202280383305867_13.jpg
#   inflating: images/ID00019637202178323708467_17.jpg
#   inflating: images/ID00213637202257692916109_226.jpg
#   inflating: images/ID00249637202266730854017_226.jpg
#   inflating: images/ID00075637202198610425520_60.jpg
#   inflating: images/ID00344637202287684217717_15.jpg
#   inflating: images/ID00111637202210956877205_236.jpg
#   inflating: images/ID00035637202182204917484_373.jpg
#   inflating: images/ID00077637202199102000916_39.jpg
#   inflating: images/ID00235637202261451839085_81.jpg
#   inflating: images/ID00192637202245493238298_190.jpg
#   inflating: images/ID00249637202266730854017_103.jpg
#   inflating: images/ID00225637202259339837603_160.jpg
#   inflating: images/ID00358637202295388077032_30.jpg
#   inflating: images/ID00213637202257692916109_105.jpg
#   inflating: images/ID00035637202182204917484_527.jpg
#   inflating: images/ID00060637202187965290703_131.jpg
#   inflating: images/ID00123637202217151272140_117.jpg
#   inflating: images/ID00109637202210454292264_291.jpg
#   inflating: images/ID00123637202217151272140_192.jpg
#   inflating: images/ID00010637202177584971671_6.jpg
#   inflating: images/ID00170637202238079193844_140.jpg
#   inflating: images/ID00192637202245493238298_172.jpg
#   inflating: images/ID00290637202279304677843_125.jpg
#   inflating: images/ID00169637202238024117706_95.jpg
#   inflating: images/ID00322637202284842245491_72.jpg
#   inflating: images/ID00192637202245493238298_78.jpg
#   inflating: images/ID00367637202296290303449_129.jpg
#   inflating: images/ID00123637202217151272140_11.jpg
#   inflating: images/ID00329637202285906759848_30.jpg
#   inflating: images/ID00426637202313170790466_321.jpg
#   inflating: images/ID00411637202309374271828_244.jpg
#   inflating: images/ID00344637202287684217717_150.jpg
#   inflating: images/ID00061637202188184085559_232.jpg
#   inflating: images/ID00186637202242472088675_113.jpg
#   inflating: images/ID00197637202246865691526_21.jpg
#   inflating: images/ID00381637202299644114027_43.jpg
#   inflating: images/ID00381637202299644114027_116.jpg
#   inflating: images/ID00140637202231728595149_61.jpg
#   inflating: images/ID00129637202219868188000_25.jpg
#   inflating: images/ID00131637202220424084844_188.jpg
#   inflating: images/ID00068637202190879923934_17.jpg
#   inflating: images/ID00290637202279304677843_133.jpg
#   inflating: images/ID00414637202310318891556_63.jpg
#   inflating: images/ID00249637202266730854017_89.jpg
#   inflating: images/ID00400637202305055099402_1.jpg
#   inflating: images/ID00061637202188184085559_19.jpg
#   inflating: images/ID00426637202313170790466_136.jpg
#   inflating: images/ID00225637202259339837603_163.jpg
#   inflating: images/ID00110637202210673668310_79.jpg
#   inflating: images/ID00414637202310318891556_11.jpg
#   inflating: images/ID00104637202208063407045_126.jpg
#   inflating: images/ID00235637202261451839085_205.jpg
#   inflating: images/ID00367637202296290303449_192.jpg
#   inflating: images/ID00192637202245493238298_31.jpg
#   inflating: images/ID00111637202210956877205_277.jpg
#   inflating: images/ID00102637202206574119190_100.jpg
#   inflating: images/ID00077637202199102000916_41.jpg
#   inflating: images/ID00048637202185016727717_15.jpg
#   inflating: images/ID00167637202237397919352_62.jpg
#   inflating: images/ID00007637202177411956430_22.jpg
#   inflating: images/ID00351637202289476567312_7.jpg
#   inflating: images/ID00130637202220059448013_48.jpg
#   inflating: images/ID00381637202299644114027_325.jpg
#   inflating: images/ID00249637202266730854017_68.jpg
#   inflating: images/ID00331637202286306023714_10.jpg
#   inflating: images/ID00329637202285906759848_163.jpg
#   inflating: images/ID00035637202182204917484_200.jpg
#   inflating: images/ID00119637202215426335765_32.jpg
#   inflating: images/ID00423637202312137826377_79.jpg
#   inflating: images/ID00196637202246668775836_70.jpg
#   inflating: images/ID00111637202210956877205_35.jpg
#   inflating: images/ID00075637202198610425520_179.jpg
#   inflating: images/ID00123637202217151272140_158.jpg
#   inflating: images/ID00186637202242472088675_11.jpg
#   inflating: images/ID00109637202210454292264_227.jpg
#   inflating: images/ID00104637202208063407045_164.jpg
#   inflating: images/ID00423637202312137826377_37.jpg
#   inflating: images/ID00184637202242062969203_13.jpg
#   inflating: images/ID00275637202271440119890_111.jpg
#   inflating: images/ID00109637202210454292264_230.jpg
#   inflating: images/ID00381637202299644114027_334.jpg
#   inflating: images/ID00426637202313170790466_247.jpg
#   inflating: images/ID00219637202258203123958_190.jpg
#   inflating: images/ID00168637202237852027833_102.jpg
#   inflating: images/ID00035637202182204917484_217.jpg
#   inflating: images/ID00015637202177877247924_99.jpg
#   inflating: images/ID00329637202285906759848_99.jpg
#   inflating: images/ID00329637202285906759848_84.jpg
#   inflating: images/ID00276637202271694539978_8.jpg
#   inflating: images/ID00225637202259339837603_11.jpg
#   inflating: images/ID00219637202258203123958_256.jpg
#   inflating: images/ID00273637202271319294586_62.jpg
#   inflating: images/ID00123637202217151272140_105.jpg
#   inflating: images/ID00411637202309374271828_77.jpg
#   inflating: images/ID00035637202182204917484_352.jpg
#   inflating: images/ID00131637202220424084844_150.jpg
#   inflating: images/ID00290637202279304677843_94.jpg
#   inflating: images/ID00139637202231703564336_44.jpg
#   inflating: images/ID00104637202208063407045_472.jpg
#   inflating: images/ID00423637202312137826377_197.jpg
#   inflating: images/ID00015637202177877247924_205.jpg
#   inflating: images/ID00360637202295712204040_184.jpg
#   inflating: images/ID00213637202257692916109_219.jpg
#   inflating: images/ID00196637202246668775836_69.jpg
#   inflating: images/ID00009637202177434476278_6.jpg
#   inflating: images/ID00370637202296737666151_133.jpg
#   inflating: images/ID00104637202208063407045_40.jpg
#   inflating: images/ID00400637202305055099402_216.jpg
#   inflating: images/ID00249637202266730854017_253.jpg
#   inflating: images/ID00170637202238079193844_83.jpg
#   inflating: images/ID00076637202199015035026_11.jpg
#   inflating: images/ID00168637202237852027833_225.jpg
#   inflating: images/ID00060637202187965290703_185.jpg
#   inflating: images/ID00035637202182204917484_300.jpg
#   inflating: images/ID00213637202257692916109_244.jpg
#   inflating: images/ID00381637202299644114027_183.jpg
#   inflating: images/ID00073637202198167792918_264.jpg
#   inflating: images/ID00219637202258203123958_83.jpg
#   inflating: images/ID00186637202242472088675_217.jpg
#   inflating: images/ID00264637202270643353440_54.jpg
#   inflating: images/ID00337637202286839091062_52.jpg
#   inflating: images/ID00073637202198167792918_349.jpg
#   inflating: images/ID00102637202206574119190_11.jpg
#   inflating: images/ID00104637202208063407045_407.jpg
#   inflating: images/ID00249637202266730854017_153.jpg
#   inflating: images/ID00073637202198167792918_300.jpg
#   inflating: images/ID00082637202201836229724_113.jpg
#   inflating: images/ID00104637202208063407045_197.jpg
#   inflating: images/ID00411637202309374271828_236.jpg
#   inflating: images/ID00032637202181710233084_166.jpg
#   inflating: images/ID00140637202231728595149_263.jpg
#   inflating: images/ID00109637202210454292264_148.jpg
#   inflating: images/ID00367637202296290303449_163.jpg
#   inflating: images/ID00411637202309374271828_65.jpg
#   inflating: images/ID00027637202179689871102_70.jpg
#   inflating: images/ID00249637202266730854017_105.jpg
#   inflating: images/ID00140637202231728595149_214.jpg
#   inflating: images/ID00119637202215426335765_66.jpg
#   inflating: images/ID00360637202295712204040_33.jpg
#   inflating: images/ID00414637202310318891556_161.jpg
#   inflating: images/ID00111637202210956877205_11.jpg
#   inflating: images/ID00131637202220424084844_84.jpg
#   inflating: images/ID00360637202295712204040_227.jpg
#   inflating: images/ID00104637202208063407045_71.jpg
#   inflating: images/ID00323637202285211956970_60.jpg
#   inflating: images/ID00168637202237852027833_170.jpg
#   inflating: images/ID00370637202296737666151_72.jpg
#   inflating: images/ID00219637202258203123958_144.jpg
#   inflating: images/ID00015637202177877247924_12.jpg
#   inflating: images/ID00225637202259339837603_96.jpg
#   inflating: images/ID00110637202210673668310_54.jpg
#   inflating: images/ID00367637202296290303449_139.jpg
#   inflating: images/ID00232637202260377586117_54.jpg
#   inflating: images/ID00123637202217151272140_183.jpg
#   inflating: images/ID00073637202198167792918_198.jpg
#   inflating: images/ID00015637202177877247924_146.jpg
#   inflating: images/ID00275637202271440119890_107.jpg
#   inflating: images/ID00082637202201836229724_62.jpg
#   inflating: images/ID00073637202198167792918_166.jpg
#   inflating: images/ID00367637202296290303449_101.jpg
#   inflating: images/ID00111637202210956877205_239.jpg
#   inflating: images/ID00130637202220059448013_43.jpg
#   inflating: images/ID00061637202188184085559_152.jpg
#   inflating: images/ID00423637202312137826377_171.jpg
#   inflating: images/ID00322637202284842245491_99.jpg
#   inflating: images/ID00170637202238079193844_25.jpg
#   inflating: images/ID00319637202283897208687_30.jpg
#   inflating: images/ID00102637202206574119190_91.jpg
#   inflating: images/ID00051637202185848464638_61.jpg
#   inflating: images/ID00370637202296737666151_84.jpg
#   inflating: images/ID00249637202266730854017_189.jpg
#   inflating: images/ID00104637202208063407045_217.jpg
#   inflating: images/ID00241637202264294508775_178.jpg
#   inflating: images/ID00290637202279304677843_86.jpg
#   inflating: images/ID00423637202312137826377_169.jpg
#   inflating: images/ID00051637202185848464638_92.jpg
#   inflating: images/ID00104637202208063407045_103.jpg
#   inflating: images/ID00249637202266730854017_248.jpg
#   inflating: images/ID00381637202299644114027_252.jpg
#   inflating: images/ID00139637202231703564336_4.jpg
#   inflating: images/ID00219637202258203123958_12.jpg
#   inflating: images/ID00032637202181710233084_126.jpg
#   inflating: images/ID00367637202296290303449_84.jpg
#   inflating: images/ID00197637202246865691526_84.jpg
#   inflating: images/ID00219637202258203123958_161.jpg
#   inflating: images/ID00167637202237397919352_116.jpg
#   inflating: images/ID00035637202182204917484_29.jpg
#   inflating: images/ID00060637202187965290703_192.jpg
#   inflating: images/ID00105637202208831864134_26.jpg
#   inflating: images/ID00129637202219868188000_18.jpg
#   inflating: images/ID00365637202296085035729_27.jpg
#   inflating: images/ID00060637202187965290703_271.jpg
#   inflating: images/ID00167637202237397919352_212.jpg
#   inflating: images/ID00398637202303897337979_20.jpg
#   inflating: images/ID00014637202177757139317_16.jpg
#   inflating: images/ID00290637202279304677843_84.jpg
#   inflating: images/ID00323637202285211956970_221.jpg
#   inflating: images/ID00007637202177411956430_10.jpg
#   inflating: images/ID00035637202182204917484_429.jpg
#   inflating: images/ID00288637202279148973731_6.jpg
#   inflating: images/ID00218637202258156844710_19.jpg
#   inflating: images/ID00109637202210454292264_150.jpg
#   inflating: images/ID00213637202257692916109_46.jpg
#   inflating: images/ID00035637202182204917484_395.jpg
#   inflating: images/ID00012637202177665765362_12.jpg
#   inflating: images/ID00035637202182204917484_306.jpg
#   inflating: images/ID00358637202295388077032_242.jpg
#   inflating: images/ID00329637202285906759848_252.jpg
#   inflating: images/ID00210637202257228694086_131.jpg
#   inflating: images/ID00417637202310901214011_34.jpg
#   inflating: images/ID00232637202260377586117_58.jpg
#   inflating: images/ID00027637202179689871102_298.jpg
#   inflating: images/ID00009637202177434476278_328.jpg
#   inflating: images/ID00168637202237852027833_82.jpg
#   inflating: images/ID00027637202179689871102_201.jpg
#   inflating: images/ID00010637202177584971671_99.jpg
#   inflating: images/ID00123637202217151272140_203.jpg
#   inflating: images/ID00123637202217151272140_209.jpg
#   inflating: images/ID00351637202289476567312_2.jpg
#   inflating: images/ID00104637202208063407045_453.jpg
#   inflating: images/ID00210637202257228694086_62.jpg
#   inflating: images/ID00104637202208063407045_286.jpg
#   inflating: images/ID00225637202259339837603_100.jpg
#   inflating: images/ID00381637202299644114027_103.jpg
#   inflating: images/ID00131637202220424084844_63.jpg
#   inflating: images/ID00170637202238079193844_166.jpg
#   inflating: images/ID00351637202289476567312_17.jpg
#   inflating: images/ID00035637202182204917484_77.jpg
#   inflating: images/ID00170637202238079193844_94.jpg
#   inflating: images/ID00169637202238024117706_4.jpg
#   inflating: images/ID00207637202252526380974_28.jpg
#   inflating: images/ID00426637202313170790466_115.jpg
#   inflating: images/ID00199637202248141386743_37.jpg
#   inflating: images/ID00360637202295712204040_99.jpg
#   inflating: images/ID00290637202279304677843_159.jpg
#   inflating: images/ID00104637202208063407045_173.jpg
#   inflating: images/ID00299637202280383305867_27.jpg
#   inflating: images/ID00167637202237397919352_70.jpg
#   inflating: images/ID00340637202287399835821_19.jpg
#   inflating: images/ID00360637202295712204040_179.jpg
#   inflating: images/ID00275637202271440119890_129.jpg
#   inflating: images/ID00417637202310901214011_24.jpg
#   inflating: images/ID00392637202302319160044_49.jpg
#   inflating: images/ID00184637202242062969203_5.jpg
#   inflating: images/ID00130637202220059448013_31.jpg
#   inflating: images/ID00129637202219868188000_23.jpg
#   inflating: images/ID00109637202210454292264_126.jpg
#   inflating: images/ID00249637202266730854017_206.jpg
#   inflating: images/ID00131637202220424084844_24.jpg
#   inflating: images/ID00110637202210673668310_118.jpg
#   inflating: images/ID00360637202295712204040_233.jpg
#   inflating: images/ID00355637202295106567614_22.jpg
#   inflating: images/ID00129637202219868188000_8.jpg
#   inflating: images/ID00275637202271440119890_187.jpg
#   inflating: images/ID00360637202295712204040_14.jpg
#   inflating: images/ID00426637202313170790466_90.jpg
#   inflating: images/ID00423637202312137826377_264.jpg
#   inflating: images/ID00358637202295388077032_12.jpg
#   inflating: images/ID00417637202310901214011_5.jpg
#   inflating: images/ID00426637202313170790466_182.jpg
#   inflating: images/ID00329637202285906759848_22.jpg
#   inflating: images/ID00035637202182204917484_468.jpg
#   inflating: images/ID00249637202266730854017_122.jpg
#   inflating: images/ID00131637202220424084844_57.jpg
#   inflating: images/ID00360637202295712204040_62.jpg
#   inflating: images/ID00367637202296290303449_233.jpg
#   inflating: images/ID00219637202258203123958_351.jpg
#   inflating: images/ID00167637202237397919352_205.jpg
#   inflating: images/ID00168637202237852027833_84.jpg
#   inflating: images/ID00241637202264294508775_67.jpg
#   inflating: images/ID00322637202284842245491_102.jpg
#   inflating: images/ID00213637202257692916109_26.jpg
#   inflating: images/ID00329637202285906759848_134.jpg
#   inflating: images/ID00186637202242472088675_63.jpg
#   inflating: images/ID00111637202210956877205_228.jpg
#   inflating: images/ID00068637202190879923934_44.jpg
#   inflating: images/ID00131637202220424084844_47.jpg
#   inflating: images/ID00299637202280383305867_5.jpg
#   inflating: images/ID00104637202208063407045_376.jpg
#   inflating: images/ID00213637202257692916109_8.jpg
#   inflating: images/ID00423637202312137826377_106.jpg
#   inflating: images/ID00090637202204766623410_56.jpg
#   inflating: images/ID00241637202264294508775_213.jpg
#   inflating: images/ID00168637202237852027833_78.jpg
#   inflating: images/ID00167637202237397919352_64.jpg
#   inflating: images/ID00111637202210956877205_157.jpg
#   inflating: images/ID00225637202259339837603_142.jpg
#   inflating: images/ID00360637202295712204040_185.jpg
#   inflating: images/ID00192637202245493238298_82.jpg
#   inflating: images/ID00035637202182204917484_450.jpg
#   inflating: images/ID00109637202210454292264_257.jpg
#   inflating: images/ID00411637202309374271828_11.jpg
#   inflating: images/ID00104637202208063407045_361.jpg
#   inflating: images/ID00110637202210673668310_57.jpg
#   inflating: images/ID00012637202177665765362_32.jpg
#   inflating: images/ID00186637202242472088675_356.jpg
#   inflating: images/ID00323637202285211956970_132.jpg
#   inflating: images/ID00218637202258156844710_15.jpg
#   inflating: images/ID00426637202313170790466_367.jpg
#   inflating: images/ID00009637202177434476278_148.jpg
#   inflating: images/ID00225637202259339837603_152.jpg
#   inflating: images/ID00104637202208063407045_212.jpg
#   inflating: images/ID00426637202313170790466_359.jpg
#   inflating: images/ID00090637202204766623410_12.jpg
#   inflating: images/ID00414637202310318891556_14.jpg
#   inflating: images/ID00225637202259339837603_88.jpg
#   inflating: images/ID00140637202231728595149_188.jpg
#   inflating: images/ID00426637202313170790466_280.jpg
#   inflating: images/ID00035637202182204917484_174.jpg
#   inflating: images/ID00322637202284842245491_63.jpg
#   inflating: images/ID00061637202188184085559_113.jpg
#   inflating: images/ID00102637202206574119190_133.jpg
#   inflating: images/ID00110637202210673668310_69.jpg
#   inflating: images/ID00426637202313170790466_377.jpg
#   inflating: images/ID00075637202198610425520_125.jpg
#   inflating: images/ID00075637202198610425520_128.jpg
#   inflating: images/ID00111637202210956877205_193.jpg
#   inflating: images/ID00219637202258203123958_226.jpg
#   inflating: images/ID00186637202242472088675_36.jpg
#   inflating: images/ID00367637202296290303449_42.jpg
#   inflating: images/ID00051637202185848464638_21.jpg
#   inflating: images/ID00082637202201836229724_238.jpg
#   inflating: images/ID00102637202206574119190_196.jpg
#   inflating: images/ID00035637202182204917484_375.jpg
#   inflating: images/ID00400637202305055099402_142.jpg
#   inflating: images/ID00102637202206574119190_173.jpg
#   inflating: images/ID00123637202217151272140_189.jpg
#   inflating: images/ID00414637202310318891556_166.jpg
#   inflating: images/ID00186637202242472088675_108.jpg
#   inflating: images/ID00073637202198167792918_318.jpg
#   inflating: images/ID00014637202177757139317_19.jpg
#   inflating: images/ID00082637202201836229724_79.jpg
#   inflating: images/ID00398637202303897337979_11.jpg
#   inflating: images/ID00170637202238079193844_165.jpg
#   inflating: images/ID00398637202303897337979_40.jpg
#   inflating: images/ID00400637202305055099402_219.jpg
#   inflating: images/ID00299637202280383305867_47.jpg
#   inflating: images/ID00219637202258203123958_252.jpg
#   inflating: images/ID00276637202271694539978_6.jpg
#   inflating: images/ID00060637202187965290703_206.jpg
#   inflating: images/ID00035637202182204917484_215.jpg
#   inflating: images/ID00109637202210454292264_64.jpg
#   inflating: images/ID00426637202313170790466_387.jpg
#   inflating: images/ID00061637202188184085559_128.jpg
#   inflating: images/ID00009637202177434476278_233.jpg
#   inflating: images/ID00207637202252526380974_45.jpg
#   inflating: images/ID00381637202299644114027_257.jpg
#   inflating: images/ID00139637202231703564336_1.jpg
#   inflating: images/ID00048637202185016727717_20.jpg
#   inflating: images/ID00411637202309374271828_143.jpg
#   inflating: images/ID00027637202179689871102_338.jpg
#   inflating: images/ID00210637202257228694086_20.jpg
#   inflating: images/ID00027637202179689871102_157.jpg
#   inflating: images/ID00275637202271440119890_48.jpg
#   inflating: images/ID00110637202210673668310_108.jpg
#   inflating: images/ID00426637202313170790466_82.jpg
#   inflating: images/ID00285637202278913507108_29.jpg
#   inflating: images/ID00360637202295712204040_262.jpg
#   inflating: images/ID00010637202177584971671_61.jpg
#   inflating: images/ID00140637202231728595149_136.jpg
#   inflating: images/ID00199637202248141386743_49.jpg
#   inflating: images/ID00329637202285906759848_182.jpg
#   inflating: images/ID00370637202296737666151_156.jpg
#   inflating: images/ID00125637202218590429387_4.jpg
#   inflating: images/ID00014637202177757139317_18.jpg
#   inflating: images/ID00168637202237852027833_22.jpg
#   inflating: images/ID00082637202201836229724_138.jpg
#   inflating: images/ID00414637202310318891556_215.jpg
#   inflating: images/ID00186637202242472088675_12.jpg
#   inflating: images/ID00027637202179689871102_292.jpg
#   inflating: images/ID00073637202198167792918_217.jpg
#   inflating: images/ID00360637202295712204040_148.jpg
#   inflating: images/ID00009637202177434476278_58.jpg
#   inflating: images/ID00104637202208063407045_409.jpg
#   inflating: images/ID00235637202261451839085_10.jpg
#   inflating: images/ID00381637202299644114027_268.jpg
#   inflating: images/ID00358637202295388077032_246.jpg
#   inflating: images/ID00015637202177877247924_250.jpg
#   inflating: images/ID00186637202242472088675_109.jpg
#   inflating: images/ID00426637202313170790466_283.jpg
#   inflating: images/ID00344637202287684217717_117.jpg
#   inflating: images/ID00123637202217151272140_187.jpg
#   inflating: images/ID00009637202177434476278_351.jpg
#   inflating: images/ID00370637202296737666151_204.jpg
#   inflating: images/ID00232637202260377586117_14.jpg
#   inflating: images/ID00360637202295712204040_243.jpg
#   inflating: images/ID00060637202187965290703_215.jpg
#   inflating: images/ID00381637202299644114027_367.jpg
#   inflating: images/ID00358637202295388077032_142.jpg
#   inflating: images/ID00235637202261451839085_97.jpg
#   inflating: images/ID00082637202201836229724_193.jpg
#   inflating: images/ID00169637202238024117706_108.jpg
#   inflating: images/ID00109637202210454292264_185.jpg
#   inflating: images/ID00426637202313170790466_155.jpg
#   inflating: images/ID00131637202220424084844_205.jpg
#   inflating: images/ID00131637202220424084844_79.jpg
#   inflating: images/ID00035637202182204917484_188.jpg
#   inflating: images/ID00082637202201836229724_253.jpg
#   inflating: images/ID00111637202210956877205_143.jpg
#   inflating: images/ID00329637202285906759848_150.jpg
#   inflating: images/ID00077637202199102000916_50.jpg
#   inflating: images/ID00111637202210956877205_20.jpg
#   inflating: images/ID00110637202210673668310_209.jpg
#   inflating: images/ID00196637202246668775836_110.jpg
#   inflating: images/ID00358637202295388077032_172.jpg
#   inflating: images/ID00010637202177584971671_24.jpg
#   inflating: images/ID00411637202309374271828_113.jpg
#   inflating: images/ID00060637202187965290703_252.jpg
#   inflating: images/ID00012637202177665765362_5.jpg
#   inflating: images/ID00123637202217151272140_225.jpg
#   inflating: images/ID00061637202188184085559_123.jpg
#   inflating: images/ID00170637202238079193844_8.jpg
#   inflating: images/ID00423637202312137826377_166.jpg
#   inflating: images/ID00218637202258156844710_21.jpg
#   inflating: images/ID00061637202188184085559_162.jpg
#   inflating: images/ID00060637202187965290703_67.jpg
#   inflating: images/ID00104637202208063407045_36.jpg
#   inflating: images/ID00365637202296085035729_12.jpg
#   inflating: images/ID00392637202302319160044_21.jpg
#   inflating: images/ID00131637202220424084844_14.jpg
#   inflating: images/ID00082637202201836229724_143.jpg
#   inflating: images/ID00210637202257228694086_22.jpg
#   inflating: images/ID00109637202210454292264_67.jpg
#   inflating: images/ID00061637202188184085559_135.jpg
#   inflating: images/ID00010637202177584971671_3.jpg
#   inflating: images/ID00186637202242472088675_238.jpg
#   inflating: images/ID00009637202177434476278_57.jpg
#   inflating: images/ID00105637202208831864134_29.jpg
#   inflating: images/ID00186637202242472088675_264.jpg
#   inflating: images/ID00082637202201836229724_124.jpg
#   inflating: images/ID00090637202204766623410_54.jpg
#   inflating: images/ID00109637202210454292264_229.jpg
# ...
#   inflating: images/ID00167637202237397919352_7.jpg
#   inflating: images/ID00219637202258203123958_309.jpg
#   inflating: images/ID00381637202299644114027_312.jpg
#   inflating: images/ID00073637202198167792918_44.jpg
#   inflating: images/ID00123637202217151272140_190.jpg
#   inflating: images/ID00035637202182204917484_34.jpg
#   inflating: images/ID00414637202310318891556_41.jpg
#   inflating: images/ID00400637202305055099402_13.jpg
#   inflating: images/ID00344637202287684217717_197.jpg
#   inflating: images/ID00073637202198167792918_207.jpg
#   inflating: images/ID00015637202177877247924_68.jpg
#   inflating: images/ID00381637202299644114027_208.jpg
#   inflating: images/ID00032637202181710233084_169.jpg
#   inflating: images/ID00102637202206574119190_174.jpg
#   inflating: images/ID00218637202258156844710_57.jpg
#   inflating: images/ID00035637202182204917484_72.jpg
#   inflating: images/ID00073637202198167792918_204.jpg
#   inflating: images/ID00075637202198610425520_74.jpg
#   inflating: images/ID00104637202208063407045_63.jpg
#   inflating: images/ID00140637202231728595149_248.jpg
#   inflating: images/ID00218637202258156844710_22.jpg
#   inflating: images/ID00186637202242472088675_196.jpg
#   inflating: images/ID00276637202271694539978_19.jpg
#   inflating: images/ID00082637202201836229724_228.jpg
#   inflating: images/ID00370637202296737666151_35.jpg
#   inflating: images/ID00210637202257228694086_292.jpg
#   inflating: images/ID00351637202289476567312_26.jpg
#   inflating: images/ID00381637202299644114027_223.jpg
#   inflating: images/ID00090637202204766623410_1.jpg
#   inflating: images/ID00060637202187965290703_269.jpg
#   inflating: images/ID00358637202295388077032_166.jpg
#   inflating: images/ID00073637202198167792918_122.jpg
#   inflating: images/ID00241637202264294508775_117.jpg
#   inflating: images/ID00197637202246865691526_36.jpg
#   inflating: images/ID00104637202208063407045_414.jpg
#   inflating: images/ID00249637202266730854017_307.jpg
#   inflating: images/ID00381637202299644114027_295.jpg
#   inflating: images/ID00104637202208063407045_364.jpg
#   inflating: images/ID00210637202257228694086_134.jpg
#   inflating: images/ID00235637202261451839085_101.jpg
#   inflating: images/ID00104637202208063407045_229.jpg
#   inflating: images/ID00235637202261451839085_64.jpg
#   inflating: images/ID00060637202187965290703_234.jpg
#   inflating: images/ID00073637202198167792918_84.jpg
#   inflating: images/ID00307637202282126172865_4.jpg
#   inflating: images/ID00131637202220424084844_22.jpg
#   inflating: images/ID00210637202257228694086_243.jpg
#   inflating: images/ID00290637202279304677843_119.jpg
#   inflating: images/ID00009637202177434476278_292.jpg
#   inflating: images/ID00249637202266730854017_212.jpg
#   inflating: images/ID00170637202238079193844_70.jpg
#   inflating: images/ID00414637202310318891556_121.jpg
#   inflating: images/ID00358637202295388077032_186.jpg
#   inflating: images/ID00019637202178323708467_4.jpg
#   inflating: images/ID00169637202238024117706_5.jpg
#   inflating: images/ID00060637202187965290703_139.jpg
#   inflating: images/ID00102637202206574119190_188.jpg
#   inflating: images/ID00109637202210454292264_30.jpg
#   inflating: images/ID00075637202198610425520_258.jpg
#   inflating: images/ID00249637202266730854017_273.jpg
#   inflating: images/ID00241637202264294508775_163.jpg
#   inflating: images/ID00267637202270790561585_22.jpg
#   inflating: images/ID00048637202185016727717_17.jpg
#   inflating: images/ID00075637202198610425520_133.jpg
#   inflating: images/ID00241637202264294508775_6.jpg
#   inflating: images/ID00073637202198167792918_156.jpg
#   inflating: images/ID00027637202179689871102_95.jpg
#   inflating: images/ID00360637202295712204040_88.jpg
#   inflating: images/ID00035637202182204917484_153.jpg
#   inflating: images/ID00426637202313170790466_287.jpg
#   inflating: images/ID00035637202182204917484_336.jpg
#   inflating: images/ID00032637202181710233084_56.jpg
#   inflating: images/ID00213637202257692916109_154.jpg
#   inflating: images/ID00241637202264294508775_16.jpg
#   inflating: images/ID00035637202182204917484_142.jpg
#   inflating: images/ID00329637202285906759848_78.jpg
#   inflating: images/ID00400637202305055099402_82.jpg
#   inflating: images/ID00126637202218610655908_2.jpg
#   inflating: images/ID00273637202271319294586_2.jpg
#   inflating: images/ID00337637202286839091062_44.jpg
#   inflating: images/ID00213637202257692916109_196.jpg
#   inflating: images/ID00102637202206574119190_143.jpg
#   inflating: images/ID00197637202246865691526_58.jpg
#   inflating: images/ID00119637202215426335765_15.jpg
#   inflating: images/ID00426637202313170790466_300.jpg
#   inflating: images/ID00423637202312137826377_81.jpg
#   inflating: images/ID00196637202246668775836_16.jpg
#   inflating: images/ID00027637202179689871102_121.jpg
#   inflating: images/ID00123637202217151272140_110.jpg
#   inflating: images/ID00423637202312137826377_267.jpg
#   inflating: images/ID00035637202182204917484_68.jpg
#   inflating: images/ID00060637202187965290703_61.jpg
#   inflating: images/ID00344637202287684217717_84.jpg
#   inflating: images/ID00009637202177434476278_103.jpg
#   inflating: images/ID00235637202261451839085_280.jpg
#   inflating: images/ID00073637202198167792918_59.jpg
#   inflating: images/ID00414637202310318891556_240.jpg
#   inflating: images/ID00426637202313170790466_204.jpg
#   inflating: images/ID00117637202212360228007_12.jpg
#   inflating: images/ID00111637202210956877205_72.jpg
#   inflating: images/ID00235637202261451839085_252.jpg
#   inflating: images/ID00235637202261451839085_219.jpg
#   inflating: images/ID00105637202208831864134_23.jpg
#   inflating: images/ID00035637202182204917484_563.jpg
#   inflating: images/ID00360637202295712204040_156.jpg
#   inflating: images/ID00241637202264294508775_161.jpg
#   inflating: images/ID00082637202201836229724_213.jpg
#   inflating: images/ID00213637202257692916109_260.jpg
#   inflating: images/ID00358637202295388077032_117.jpg
#   inflating: images/ID00104637202208063407045_463.jpg
#   inflating: images/ID00192637202245493238298_226.jpg
#   inflating: images/ID00358637202295388077032_173.jpg
#   inflating: images/ID00035637202182204917484_14.jpg
#   inflating: images/ID00123637202217151272140_3.jpg
#   inflating: images/ID00027637202179689871102_128.jpg
#   inflating: images/ID00104637202208063407045_129.jpg
#   inflating: images/ID00027637202179689871102_267.jpg
#   inflating: images/ID00329637202285906759848_217.jpg
#   inflating: images/ID00367637202296290303449_9.jpg
#   inflating: images/ID00358637202295388077032_70.jpg
#   inflating: images/ID00075637202198610425520_297.jpg
#   inflating: images/ID00051637202185848464638_73.jpg
#   inflating: images/ID00210637202257228694086_278.jpg
#   inflating: images/ID00027637202179689871102_174.jpg
#   inflating: images/ID00218637202258156844710_4.jpg
#   inflating: images/ID00370637202296737666151_153.jpg
#   inflating: images/ID00060637202187965290703_109.jpg
#   inflating: images/ID00186637202242472088675_302.jpg
#   inflating: images/ID00102637202206574119190_185.jpg
#   inflating: images/ID00196637202246668775836_82.jpg
#   inflating: images/ID00421637202311550012437_24.jpg
#   inflating: images/ID00241637202264294508775_54.jpg
#   inflating: images/ID00123637202217151272140_86.jpg
#   inflating: images/ID00068637202190879923934_27.jpg
#   inflating: images/ID00249637202266730854017_269.jpg
#   inflating: images/ID00241637202264294508775_217.jpg
#   inflating: images/ID00060637202187965290703_191.jpg
#   inflating: images/ID00305637202281772703145_8.jpg
#   inflating: images/ID00235637202261451839085_30.jpg
#   inflating: images/ID00426637202313170790466_225.jpg
#   inflating: images/ID00275637202271440119890_32.jpg
#   inflating: images/ID00027637202179689871102_195.jpg
#   inflating: images/ID00319637202283897208687_29.jpg
#   inflating: images/ID00225637202259339837603_185.jpg
#   inflating: images/ID00219637202258203123958_272.jpg
#   inflating: images/ID00232637202260377586117_23.jpg
#   inflating: images/ID00060637202187965290703_42.jpg
#   inflating: images/ID00035637202182204917484_361.jpg
#   inflating: images/ID00299637202280383305867_12.jpg
#   inflating: images/ID00186637202242472088675_152.jpg
#   inflating: images/ID00360637202295712204040_244.jpg
#   inflating: images/ID00186637202242472088675_214.jpg
#   inflating: images/ID00219637202258203123958_168.jpg
#   inflating: images/ID00111637202210956877205_154.jpg
#   inflating: images/ID00131637202220424084844_77.jpg
#   inflating: images/ID00426637202313170790466_109.jpg
#   inflating: images/ID00061637202188184085559_40.jpg
#   inflating: images/ID00167637202237397919352_18.jpg
#   inflating: images/ID00186637202242472088675_188.jpg
#   inflating: images/ID00360637202295712204040_18.jpg
#   inflating: images/ID00035637202182204917484_355.jpg
#   inflating: images/ID00126637202218610655908_9.jpg
#   inflating: images/ID00264637202270643353440_34.jpg
#   inflating: images/ID00082637202201836229724_192.jpg
#   inflating: images/ID00367637202296290303449_171.jpg
#   inflating: images/ID00207637202252526380974_13.jpg
#   inflating: images/ID00073637202198167792918_306.jpg
#   inflating: images/ID00140637202231728595149_15.jpg
#   inflating: images/ID00290637202279304677843_163.jpg
#   inflating: images/ID00130637202220059448013_46.jpg
#   inflating: images/ID00060637202187965290703_136.jpg
#   inflating: images/ID00423637202312137826377_31.jpg
#   inflating: images/ID00358637202295388077032_301.jpg
#   inflating: images/ID00407637202308788732304_11.jpg
#   inflating: images/ID00219637202258203123958_57.jpg
#   inflating: images/ID00061637202188184085559_160.jpg
#   inflating: images/ID00290637202279304677843_44.jpg
#   inflating: images/ID00035637202182204917484_383.jpg
#   inflating: images/ID00218637202258156844710_38.jpg
#   inflating: images/ID00015637202177877247924_48.jpg
#   inflating: images/ID00241637202264294508775_41.jpg
#   inflating: images/ID00168637202237852027833_124.jpg
#   inflating: images/ID00167637202237397919352_188.jpg
#   inflating: images/ID00331637202286306023714_12.jpg
#   inflating: images/ID00370637202296737666151_159.jpg
#   inflating: images/ID00197637202246865691526_57.jpg
#   inflating: images/ID00344637202287684217717_158.jpg
#   inflating: images/ID00167637202237397919352_206.jpg
#   inflating: images/ID00169637202238024117706_17.jpg
#   inflating: images/ID00119637202215426335765_39.jpg
#   inflating: images/ID00241637202264294508775_45.jpg
#   inflating: images/ID00102637202206574119190_230.jpg
#   inflating: images/ID00344637202287684217717_51.jpg
#   inflating: images/ID00068637202190879923934_2.jpg
#   inflating: images/ID00249637202266730854017_310.jpg
#   inflating: images/ID00061637202188184085559_191.jpg
#   inflating: images/ID00061637202188184085559_47.jpg
#   inflating: images/ID00015637202177877247924_54.jpg
#   inflating: images/ID00340637202287399835821_9.jpg
#   inflating: images/ID00119637202215426335765_25.jpg
#   inflating: images/ID00426637202313170790466_351.jpg
#   inflating: images/ID00075637202198610425520_277.jpg
#   inflating: images/ID00392637202302319160044_30.jpg
#   inflating: images/ID00015637202177877247924_262.jpg
#   inflating: images/ID00329637202285906759848_115.jpg
#   inflating: images/ID00032637202181710233084_172.jpg
#   inflating: images/ID00027637202179689871102_104.jpg
#   inflating: images/ID00123637202217151272140_185.jpg
#   inflating: images/ID00104637202208063407045_75.jpg
#   inflating: images/ID00426637202313170790466_320.jpg
#   inflating: images/ID00329637202285906759848_86.jpg
#   inflating: images/ID00426637202313170790466_402.jpg
#   inflating: images/ID00423637202312137826377_13.jpg
#   inflating: images/ID00319637202283897208687_20.jpg
#   inflating: images/ID00367637202296290303449_156.jpg
#   inflating: images/ID00015637202177877247924_238.jpg
#   inflating: images/ID00139637202231703564336_62.jpg
#   inflating: images/ID00123637202217151272140_46.jpg
#   inflating: images/ID00140637202231728595149_44.jpg
#   inflating: images/ID00290637202279304677843_132.jpg
#   inflating: images/ID00111637202210956877205_248.jpg
#   inflating: images/ID00060637202187965290703_106.jpg
#   inflating: images/ID00275637202271440119890_221.jpg
#   inflating: images/ID00015637202177877247924_106.jpg
#   inflating: images/ID00421637202311550012437_34.jpg
#   inflating: images/ID00019637202178323708467_2.jpg
#   inflating: images/ID00104637202208063407045_86.jpg
#   inflating: images/ID00123637202217151272140_136.jpg
#   inflating: images/ID00329637202285906759848_8.jpg
#   inflating: images/ID00170637202238079193844_78.jpg
#   inflating: images/ID00196637202246668775836_56.jpg
#   inflating: images/ID00131637202220424084844_195.jpg
#   inflating: images/ID00073637202198167792918_95.jpg
#   inflating: images/ID00102637202206574119190_49.jpg
#   inflating: images/ID00111637202210956877205_18.jpg
#   inflating: images/ID00027637202179689871102_296.jpg
#   inflating: images/ID00123637202217151272140_36.jpg
#   inflating: images/ID00219637202258203123958_42.jpg
#   inflating: images/ID00192637202245493238298_185.jpg
#   inflating: images/ID00381637202299644114027_31.jpg
#   inflating: images/ID00360637202295712204040_11.jpg
#   inflating: images/ID00186637202242472088675_346.jpg
#   inflating: images/ID00213637202257692916109_135.jpg
#   inflating: images/ID00032637202181710233084_70.jpg
#   inflating: images/ID00411637202309374271828_203.jpg
#   inflating: images/ID00111637202210956877205_23.jpg
#   inflating: images/ID00104637202208063407045_213.jpg
#   inflating: images/ID00426637202313170790466_386.jpg
#   inflating: images/ID00364637202296074419422_27.jpg
#   inflating: images/ID00322637202284842245491_33.jpg
#   inflating: images/ID00007637202177411956430_6.jpg
#   inflating: images/ID00411637202309374271828_95.jpg
#   inflating: images/ID00015637202177877247924_233.jpg
#   inflating: images/ID00235637202261451839085_123.jpg
#   inflating: images/ID00102637202206574119190_5.jpg
#   inflating: images/ID00210637202257228694086_276.jpg
#   inflating: images/ID00140637202231728595149_55.jpg
#   inflating: images/ID00122637202216437668965_64.jpg
#   inflating: images/ID00082637202201836229724_107.jpg
#   inflating: images/ID00210637202257228694086_109.jpg
#   inflating: images/ID00009637202177434476278_342.jpg
#   inflating: images/ID00392637202302319160044_23.jpg
#   inflating: images/ID00169637202238024117706_27.jpg
#   inflating: images/ID00323637202285211956970_1.jpg
#   inflating: images/ID00290637202279304677843_4.jpg
#   inflating: images/ID00073637202198167792918_98.jpg
#   inflating: images/ID00360637202295712204040_181.jpg
#   inflating: images/ID00305637202281772703145_59.jpg
#   inflating: images/ID00035637202182204917484_65.jpg
#   inflating: images/ID00184637202242062969203_37.jpg
#   inflating: images/ID00400637202305055099402_72.jpg
#   inflating: images/ID00102637202206574119190_200.jpg
#   inflating: images/ID00035637202182204917484_196.jpg
#   inflating: images/ID00123637202217151272140_97.jpg
#   inflating: images/ID00032637202181710233084_60.jpg
#   inflating: images/ID00329637202285906759848_226.jpg
#   inflating: images/ID00411637202309374271828_217.jpg
#   inflating: images/ID00168637202237852027833_244.jpg
#   inflating: images/ID00110637202210673668310_65.jpg
#   inflating: images/ID00123637202217151272140_129.jpg
#   inflating: images/ID00426637202313170790466_405.jpg
#   inflating: images/ID00414637202310318891556_216.jpg
#   inflating: images/ID00061637202188184085559_112.jpg
#   inflating: images/ID00111637202210956877205_274.jpg
#   inflating: images/ID00381637202299644114027_163.jpg
#   inflating: images/ID00123637202217151272140_98.jpg
#   inflating: images/ID00225637202259339837603_22.jpg
#   inflating: images/ID00290637202279304677843_137.jpg

# %%
# !pip install albumentations==0.4.6
# !pip install git+https://github.com/qubvel/segmentation_models.pytorch
# Out:
# Collecting albumentations==0.4.6
#   Downloading albumentations-0.4.6.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 1.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from albumentations==0.4.6) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from albumentations==0.4.6) (1.11.4)
# Requirement already satisfied: imgaug>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==0.4.6) (0.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations==0.4.6) (6.0.1)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations==0.4.6) (4.8.0.76)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug>=0.4.0->albumentations==0.4.6) (1.16.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from imgaug>=0.4.0->albumentations==0.4.6) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug>=0.4.0->albumentations==0.4.6) (3.7.1)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from imgaug>=0.4.0->albumentations==0.4.6) (0.19.3)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug>=0.4.0->albumentations==0.4.6) (2.31.6)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug>=0.4.0->albumentations==0.4.6) (2.0.2)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->albumentations==0.4.6) (3.2.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->albumentations==0.4.6) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->albumentations==0.4.6) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->albumentations==0.4.6) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.4.6) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.4.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.4.6) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.4.6) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.4.6) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.4.6) (2.8.2)
# Building wheels for collected packages: albumentations
#   Building wheel for albumentations (setup.py) ... done
#   Created wheel for albumentations: filename=albumentations-0.4.6-py3-none-any.whl size=65152 sha256=33ba2dc6e4fd80d3e8da3488ba1ea4041cf8d29172e897784e6be86cdc7244c6
#   Stored in directory: /root/.cache/pip/wheels/f9/d7/0c/6ed42fd872f7d1af78b25045f8b16be330f2c70ae72c83e37d
# Successfully built albumentations
# Installing collected packages: albumentations
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.3.1
#     Uninstalling albumentations-1.3.1:
#       Successfully uninstalled albumentations-1.3.1
# Successfully installed albumentations-0.4.6
# Collecting git+https://github.com/qubvel/segmentation_models.pytorch
#   Cloning https://github.com/qubvel/segmentation_models.pytorch to /tmp/pip-req-build-m2ffp36t
#   Running command git clone --filter=blob:none --quiet https://github.com/qubvel/segmentation_models.pytorch /tmp/pip-req-build-m2ffp36t
#   Resolved https://github.com/qubvel/segmentation_models.pytorch to commit 6db76a1106426ac5b55f39fba68168f3bccae7f8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch==0.3.3) (0.16.0+cu118)
# Collecting pretrainedmodels==0.7.4 (from segmentation-models-pytorch==0.3.3)
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 972.5 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting efficientnet-pytorch==0.7.1 (from segmentation-models-pytorch==0.3.3)
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting timm==0.9.7 (from segmentation-models-pytorch==0.3.3)
#   Downloading timm-0.9.7-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch==0.3.3) (4.66.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch==0.3.3) (9.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch==0.3.3) (1.16.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.3) (2.1.0+cu118)
# Collecting munch (from pretrainedmodels==0.7.4->segmentation-models-pytorch==0.3.3)
#   Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm==0.9.7->segmentation-models-pytorch==0.3.3) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm==0.9.7->segmentation-models-pytorch==0.3.3) (0.19.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm==0.9.7->segmentation-models-pytorch==0.3.3) (0.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch==0.3.3) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch==0.3.3) (2.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.3) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.3) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.3) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.3) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.3) (2.1.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.9.7->segmentation-models-pytorch==0.3.3) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch==0.3.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch==0.3.3) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch==0.3.3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch==0.3.3) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch==0.3.3) (1.3.0)
# Building wheels for collected packages: segmentation-models-pytorch, efficientnet-pytorch, pretrainedmodels
#   Building wheel for segmentation-models-pytorch (pyproject.toml) ... done
#   Created wheel for segmentation-models-pytorch: filename=segmentation_models_pytorch-0.3.3-py3-none-any.whl size=106723 sha256=01a04bbb231959b08edce951086d6800f032106d878444c002e7c40c4e04b5d0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xi25__v6/wheels/1a/49/5f/858bc2741660e381e83f1d8b297edc4d9f0561f29becaee577
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16428 sha256=8fe40f1547d2378dbbfcdbe4d58a5d0a4916977b36ae518b70010c5f79e47746
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60945 sha256=602cfdd6c333cb430d9851ff61f8b4c12e6633f6ca3199dd953e0261f325274f
#   Stored in directory: /root/.cache/pip/wheels/35/cb/a5/8f534c60142835bfc889f9a482e4a67e0b817032d9c6883b64
# Successfully built segmentation-models-pytorch efficientnet-pytorch pretrainedmodels
# Installing collected packages: munch, efficientnet-pytorch, timm, pretrainedmodels, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.7.1 munch-4.0.0 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.3.3 timm-0.9.7

# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import os
import time
import io
import base64

import numpy as np
import pandas as pd
import cv2

import matplotlib.pyplot as plt
import matplotlib.colors as mpl_colors
import seaborn as sns

from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau

from albumentations.pytorch import ToTensor, ToTensorV2
from albumentations import (HorizontalFlip,
                            VerticalFlip,
                            Normalize,
                            Compose)

from segmentation_models_pytorch import Unet

from IPython.display import HTML
from IPython.display import clear_output
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ## HELPER FUNCS.

# %%
# utils
def get_one_slice_data(img_name: str,
                       mask_name: str,
                       root_imgs_path: str = "/content/images",
                       root_masks_path: str = "masks/",) -> np.ndarray:

    img_path = os.path.join(root_imgs_path, img_name)
    mask_path = os.path.join(root_masks_path, mask_name)
    one_slice_img = cv2.imread(img_path)#[:,:,0] uncomment for grayscale
    one_slice_mask = cv2.imread(mask_path)
    one_slice_mask[one_slice_mask < 240] = 0  # remove artifacts
    one_slice_mask[one_slice_mask >= 240] = 255

    return one_slice_img, one_slice_mask


def get_id_predictions(net: nn.Module,
                       ct_scan_id_df: pd.DataFrame,
                       root_imgs_dir: str,
                       treshold: float = 0.3) -> list:

    """
    Factory for getting predictions and storing them and images in lists as uint8 images.
    Params:
        net: model for prediction.
        ct_scan_id_df: df with unique patient id.
        root_imgs_dir: root path for images.
        treshold: threshold for probabilities.
    """
    sigmoid = lambda x: 1 / (1 + np.exp(-x))
    images = []
    predictions = []
    net.eval()
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print("device:", device)
    with torch.no_grad():
        for idx in range(len(ct_scan_id_df)):
            img_name = ct_scan_id_df.loc[idx, "ImageId"]
            path = os.path.join(root_imgs_dir, img_name)

            img_ = cv2.imread(path)

            img = Normalize().apply(img_)
            tensor = torch.FloatTensor(img).permute(2, 0, 1).unsqueeze(0)
            prediction = net.forward(tensor.to(device))
            prediction = prediction.cpu().detach().numpy()
            prediction = prediction.squeeze(0).transpose(1, 2, 0)
            prediction = sigmoid(prediction)
            prediction = (prediction >= treshold).astype(np.float32)

            predictions.append((prediction * 255).astype("uint8"))
            images.append(img_)

    return images, predictions


# Save image in original resolution
# helpful link - https://stackoverflow.com/questions/34768717/matplotlib-unable-to-save-image-in-same-resolution-as-original-image

def get_overlaid_masks_on_image(
                one_slice_image: np.ndarray,
                one_slice_mask: np.ndarray,
                w: float = 512,
                h: float = 512,
                dpi: float = 100,
                write: bool = False,
                path_to_save: str = '/content/',
                name_to_save: str = 'img_name'):
    """overlap masks on image and save this as a new image."""

    path_to_save_ = os.path.join(path_to_save, name_to_save)
    lung, heart, trachea = [one_slice_mask[:, :, i] for i in range(3)]
    figsize = (w / dpi), (h / dpi)
    fig = plt.figure(figsize=(figsize))
    fig.add_axes([0, 0, 1, 1])

    # image
    plt.imshow(one_slice_image, cmap="bone")

    # overlaying segmentation masks
    plt.imshow(np.ma.masked_where(lung == False, lung),
            cmap='cool', alpha=0.3)
    plt.imshow(np.ma.masked_where(heart == False, heart),
            cmap='autumn', alpha=0.3)
    plt.imshow(np.ma.masked_where(trachea == False, trachea),
               cmap='autumn_r', alpha=0.3)

    #plt.axis("off")                                            ## dont work in kaggle kernel
    fig.axes[0].get_xaxis().set_visible(False)                  ## work in kaggle kernel
    fig.axes[0].get_yaxis().set_visible(False)


    fig.savefig(f"{path_to_save_}.png",bbox_inches='tight',
                pad_inches=0, dpi=dpi,  format="png")

    if write:
        plt.close()
    else:
        plt.show()

def get_overlaid_masks_on_full_ctscan(ct_scan_id_df: pd.DataFrame,
                                      path_to_save: str,
                                      root_imgs_dir: str,
                                      root_masks_dir: str,
                                     ):
    """
    Creating images with overlaid masks on each slice of CT scan.
    Params:
         ct_scan_id_df: df with unique patient id.
         path_to_save: path to save images.
    """
    num_slice = len(ct_scan_id_df)
    for slice_ in range(num_slice):
        img_name = ct_scan_id_df.loc[slice_, "ImageId"]
        mask_name = ct_scan_id_df.loc[slice_, "MaskId"]
        one_slice_img, one_slice_mask = get_one_slice_data(img_name, mask_name,
                                                           root_imgs_dir, root_masks_dir)
        get_overlaid_masks_on_image(one_slice_img,
                                one_slice_mask,
                                write=True,
                                path_to_save=path_to_save,
                                name_to_save=str(slice_)
                                )

def create_video(path_to_imgs: str, video_name: str, framerate: int):
    """
    Create video from images.
    Params:
        path_to_imgs: path to dir with images.
        video_name: name for saving video.
        framerate: num frames per sec in video.
    """
    img_names = sorted(os.listdir(path_to_imgs), key=lambda x: int(x[:-4]))  # img_name must be numbers
    img_path = os.path.join(path_to_imgs, img_names[0])
    frame_width, frame_height, _ = cv2.imread(img_path).shape
    fourc = cv2.VideoWriter_fourcc(*'XVID')           ## MP4V - dont work in kaggle kernel
    video = cv2.VideoWriter(video_name + ".avi",      ##'mp4'
                            fourc,
                            framerate,
                            (frame_width, frame_height))

    for img_name in img_names:
        img_path = os.path.join(path_to_imgs, img_name)
        image = cv2.imread(img_path)
        video.write(image)

    cv2.destroyAllWindows()
    video.release()


def compute_scores_per_classes(model,
                               dataloader,
                               classes):
    """
    Compute Dice and Jaccard coefficients for each class.
    Params:
        model: neural net for make predictions.
        dataloader: dataset object to load data from.
        classes: list with classes.
        Returns: dictionaries with dice and jaccard coefficients for each class for each slice.
    """
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    dice_scores_per_classes = {key: list() for key in classes}
    iou_scores_per_classes = {key: list() for key in classes}

    with torch.no_grad():
        for i, (imgs, targets) in enumerate(dataloader):
            imgs, targets = imgs.to(device), targets.to(device)
            logits = model(imgs)
            logits = logits.detach().cpu().numpy()
            targets = targets.detach().cpu().numpy()

            dice_scores = dice_coef_metric_per_classes(logits, targets)
            iou_scores = jaccard_coef_metric_per_classes(logits, targets)

            for key in dice_scores.keys():
                dice_scores_per_classes[key].extend(dice_scores[key])

            for key in iou_scores.keys():
                iou_scores_per_classes[key].extend(iou_scores[key])

    return dice_scores_per_classes, iou_scores_per_classes


# loss
def dice_coef_metric_per_classes(probabilities: np.ndarray,
                                    truth: np.ndarray,
                                    treshold: float = 0.5,
                                    eps: float = 1e-9,
                                    classes: list = ['lung', 'heart', 'trachea']) -> np.ndarray:
    """
    Calculate Dice score for data batch and for each class.
    Params:
        probobilities: model outputs after activation function.
        truth: model targets.
        threshold: threshold for probabilities.
        eps: additive to refine the estimate.
        classes: list with name classes.
        Returns: dict with dice scores for each class.
    """
    scores = {key: list() for key in classes}
    num = probabilities.shape[0]
    num_classes = probabilities.shape[1]
    predictions = (probabilities >= treshold).astype(np.float32)
    assert(predictions.shape == truth.shape)

    for i in range(num):
        for class_ in range(num_classes):
            prediction = predictions[i][class_]
            truth_ = truth[i][class_]
            intersection = 2.0 * (truth_ * prediction).sum()
            union = truth_.sum() + prediction.sum()
            if truth_.sum() == 0 and prediction.sum() == 0:
                 scores[classes[class_]].append(1.0)
            else:
                scores[classes[class_]].append((intersection + eps) / union)

    return scores


def jaccard_coef_metric_per_classes(probabilities: np.ndarray,
               truth: np.ndarray,
               treshold: float = 0.5,
               eps: float = 1e-9,
               classes: list = ['lung', 'heart', 'trachea']) -> np.ndarray:
    """
    Calculate Jaccard index for data batch and for each class.
    Params:
        probobilities: model outputs after activation function.
        truth: model targets.
        threshold: threshold for probabilities.
        eps: additive to refine the estimate.
        classes: list with name classes.
        Returns: dict with jaccard scores for each class."
    """
    scores = {key: list() for key in classes}
    num = probabilities.shape[0]
    num_classes = probabilities.shape[1]
    predictions = (probabilities >= treshold).astype(np.float32)
    assert(predictions.shape == truth.shape)

    for i in range(num):
        for class_ in range(num_classes):
            prediction = predictions[i][class_]
            truth_ = truth[i][class_]
            intersection = (prediction * truth_).sum()
            union = (prediction.sum() + truth_.sum()) - intersection + eps
            if truth_.sum() == 0 and prediction.sum() == 0:
                 scores[classes[class_]].append(1.0)
            else:
                scores[classes[class_]].append((intersection + eps) / union)

    return scores


# visualizer
def show_data_augmentations(img_tensor: torch.Tensor,
                            mask_tensor: torch.Tensor,
                            mean: tuple = (0.485, 0.456, 0.406),
                            std: tuple = (0.229, 0.224, 0.225),
                            labels: list=["image", "lung", "heart", "trachea"]):

    img = img_tensor.numpy().transpose(1, 2, 0)
    img = (img * std + mean).astype("float32")
    img = np.clip(img, 0, 1)
    mask = mask_tensor.numpy().transpose(1, 2, 0)
    data_to_plot = [img, *[mask[:,:, i] for i in range(3)]]

    fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(15, 8))
    for i, ax in enumerate(axes):
        ax.imshow(data_to_plot[i])
        ax.set_title(labels[i])

    plt.show()


def show_video(video_path: str):
    """
    show video in jupyter notebook, agent interaction in environment.
    Takes - path to video file.
    Returns - html video player in jupyter notebook.
    """
    video = io.open(video_path, 'r+b').read()
    encoded = base64.b64encode(video)

    return HTML(data='''<video alt="test" controls>
    <source src="data:video/mp4;base64,{0}" type="video/mp4" /> </video>'''
    .format(encoded.decode('ascii')))


def get_color_info(classes: list = ['lung', 'heart', 'trachea']):

    def get_color(cmap):
        new_cmap = mpl_colors.LinearSegmentedColormap.from_list(
            (cmap.name, 0.0, 0.0,),
            cmap(np.linspace(0.0, 0.0, 100))
            )
        return new_cmap

    colormaps = [plt.get_cmap(cmap_name) for cmap_name in
                ['cool', 'autumn', 'autumn_r']
                ]
    arr = np.linspace(0, 50, 100).reshape((10, 10))
    fig, ax = plt.subplots(1, 3, figsize=(15, 5))
    for i in range(3):
        cmap = get_color(colormaps[i])
        ax[i].axis('off')
        ax[i].imshow(arr, cmap=cmap)
        ax[i].set_title(classes[i], fontsize=15)

    fig.suptitle("Color definition", fontsize=20, y=0.99)
    fig.savefig(f"color_definition.png", bbox_inches='tight',
                pad_inches=0.2, dpi=100, format="png")

    plt.savefig(f"color_definition.svg", bbox_inches='tight',
                pad_inches=0.2, dpi=100, format="svg")

# %% [markdown]
# config with global variables

# %%
class GlobalConfig:
    def __init__(self):
        self.seed = 555
        self.path_to_csv = '/content/slide.csv'
        self.path_to_imgs_dir = '/content/images'
        self.path_to_masks_dir = '/content/masks'
        self.pretrained_model_path = '/content/sample_data/last_epoch_model.pth'
        self.train_logs_path = '/content/sample_data/train_log.csv'


def seed_everything(seed: int):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    np.random.seed(seed)

config = GlobalConfig()
seed_everything(config.seed)

# %% [markdown]
# ## DATASET AND DATALOADERS

# %%
class LungsDataset(Dataset):
    def __init__(self,
                 imgs_dir: str,
                 masks_dir:str,
                 df: pd.DataFrame,
                 phase: str):
        """Initialization."""
        self.root_imgs_dir = imgs_dir
        self.root_masks_dir = masks_dir
        self.df = df
        self.augmentations = get_augmentations(phase)

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_name = self.df.loc[idx, "ImageId"]
        mask_name = self.df.loc[idx, "MaskId"]
        img_path = os.path.join(self.root_imgs_dir, img_name)
        mask_path = os.path.join(self.root_masks_dir, mask_name)
        img = cv2.imread(img_path)
        mask = cv2.imread(mask_path)
        mask[mask < 240] = 0    # remove artifacts
        mask[mask > 0] = 1

        augmented = self.augmentations(image=img,
                                       mask=mask.astype(np.float32))
        img = augmented['image']
        mask = augmented['mask'].permute(2, 0, 1)

        return img, mask


def get_augmentations(phase,
                   mean: tuple = (0.485, 0.456, 0.406),
                   std: tuple = (0.229, 0.224, 0.225),):
    list_transforms = []
    if phase == "train":
        list_transforms.extend(
            [
                VerticalFlip(p=0.5),
            ]
        )
    list_transforms.extend(
        [
            Normalize(mean=mean, std=std, p=1),
            #ToTensor(num_classes=3, sigmoid=False),
            ToTensorV2(),
        ]
    )
    list_trfms = Compose(list_transforms)
    return list_trfms


def get_dataloader(
    imgs_dir: str,
    masks_dir: str,
    path_to_csv: str,
    phase: str,
    batch_size: int = 8,
    num_workers: int = 6,
    test_size: float = 0.2,
):
    '''Returns: dataloader for the model training'''
    df = pd.read_csv(path_to_csv)


    train_df, val_df = train_test_split(df,
                                          test_size=test_size,
                                          random_state=69)
    train_df, val_df = train_df.reset_index(drop=True), val_df.reset_index(drop=True)

    df = train_df if phase == "train" else val_df
    image_dataset = LungsDataset(imgs_dir, masks_dir, df, phase)
    dataloader = DataLoader(
        image_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        pin_memory=True,
        shuffle=True,
    )

    return dataloader

# %% [markdown]
# ## LOSS AND EVALUATION

# %%
def dice_coef_metric(probabilities: torch.Tensor,
                     truth: torch.Tensor,
                     treshold: float = 0.5,
                     eps: float = 1e-9) -> np.ndarray:
    """
    Calculate Dice score for data batch.
    Params:
        probobilities: model outputs after activation function.
        truth: truth values.
        threshold: threshold for probabilities.
        eps: additive to refine the estimate.
        Returns: dice score aka f1.
    """
    scores = []
    num = probabilities.shape[0]
    predictions = (probabilities >= treshold).float()
    assert(predictions.shape == truth.shape)
    for i in range(num):
        prediction = predictions[i]
        truth_ = truth[i]
        intersection = 2.0 * (truth_ * prediction).sum()
        union = truth_.sum() + prediction.sum()
        if truth_.sum() == 0 and prediction.sum() == 0:
            scores.append(1.0)
        else:
            scores.append((intersection + eps) / union)
    return np.mean(scores)


def jaccard_coef_metric(probabilities: torch.Tensor,
               truth: torch.Tensor,
               treshold: float = 0.5,
               eps: float = 1e-9) -> np.ndarray:
    """
    Calculate Jaccard index for data batch.
    Params:
        probobilities: model outputs after activation function.
        truth: truth values.
        threshold: threshold for probabilities.
        eps: additive to refine the estimate.
        Returns: jaccard score aka iou."
    """
    scores = []
    num = probabilities.shape[0]
    predictions = (probabilities >= treshold).float()
    assert(predictions.shape == truth.shape)

    for i in range(num):
        prediction = predictions[i]
        truth_ = truth[i]
        intersection = (prediction * truth_).sum()
        union = (prediction.sum() + truth_.sum()) - intersection + eps
        if truth_.sum() == 0 and prediction.sum() == 0:
            scores.append(1.0)
        else:
            scores.append((intersection + eps) / union)
    return np.mean(scores)


class Meter:
    '''factory for storing and updating iou and dice scores.'''
    def __init__(self, treshold: float = 0.5):
        self.threshold: float = treshold
        self.dice_scores: list = []
        self.iou_scores: list = []

    def update(self, logits: torch.Tensor, targets: torch.Tensor):
        """
        Takes: logits from output model and targets,
        calculates dice and iou scores, and stores them in lists.
        """
        probs = torch.sigmoid(logits)
        dice = dice_coef_metric(probs, targets, self.threshold)
        iou = jaccard_coef_metric(probs, targets, self.threshold)

        self.dice_scores.append(dice)
        self.iou_scores.append(iou)

    def get_metrics(self) -> np.ndarray:
        """
        Returns: the average of the accumulated dice and iou scores.
        """
        dice = np.mean(self.dice_scores)
        iou = np.mean(self.iou_scores)
        return dice, iou


class DiceLoss(nn.Module):
    """Calculate dice loss."""
    def __init__(self, eps: float = 1e-9):
        super(DiceLoss, self).__init__()
        self.eps = eps

    def forward(self,
                logits: torch.Tensor,
                targets: torch.Tensor) -> torch.Tensor:

        num = targets.size(0)
        probability = torch.sigmoid(logits)
        probability = probability.view(num, -1)
        targets = targets.view(num, -1)
        assert(probability.shape == targets.shape)

        intersection = 2.0 * (probability * targets).sum()
        union = probability.sum() + targets.sum()
        dice_score = (intersection + self.eps) / union
        #print("intersection", intersection, union, dice_score)
        return 1.0 - dice_score


class BCEDiceLoss(nn.Module):
    """Compute objective loss: BCE loss + DICE loss."""
    def __init__(self):
        super(BCEDiceLoss, self).__init__()
        self.bce = nn.BCEWithLogitsLoss()
        self.dice = DiceLoss()

    def forward(self,
                logits: torch.Tensor,
                targets: torch.Tensor) -> torch.Tensor:
        assert(logits.shape == targets.shape)
        dice_loss = self.dice(logits, targets)
        bce_loss = self.bce(logits, targets)

        return bce_loss + dice_loss

# %% [markdown]
# ## MODEL

# %%
model = Unet('efficientnet-b2', encoder_weights="imagenet", classes=3, activation=None)
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b2-8bb594d6.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b2-8bb594d6.pth
# 100%|██████████| 35.1M/35.1M [00:00<00:00, 113MB/s]

# %% [markdown]
# # TRAIN PROCESS

# %%
class Trainer:
    """
    Factory for training proccess.
    Args:
        display_plot: if True - plot train history after each epoch.
        net: neural network for mask prediction.
        criterion: factory for calculating objective loss.
        optimizer: optimizer for weights updating.
        phases: list with train and validation phases.
        dataloaders: dict with data loaders for train and val phases.
        imgs_dir: path to folder with images.
        masks_dir: path to folder with imasks.
        path_to_csv: path to csv file.
        meter: factory for storing and updating metrics.
        batch_size: data batch size for one step weights updating.
        num_epochs: num weights updation for all data.
        accumulation_steps: the number of steps after which the optimization step can be taken
                    (https://www.kaggle.com/c/understanding_cloud_organization/discussion/105614).
        lr: learning rate for optimizer.
        scheduler: scheduler for control learning rate.
        losses: dict for storing lists with losses for each phase.
        jaccard_scores: dict for storing lists with jaccard scores for each phase.
        dice_scores: dict for storing lists with dice scores for each phase.
    """
    def __init__(self,
                 net: nn.Module,
                 criterion: nn.Module,
                 lr: float,
                 accumulation_steps: int,
                 batch_size: int,
                 num_epochs: int,
                 imgs_dir: str,
                 masks_dir: str,
                 path_to_csv: str,
                 display_plot: bool = True
                ):

        """Initialization."""
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        print("device:", self.device)
        self.display_plot = display_plot
        self.net = net
        self.net = self.net.to(self.device)
        self.criterion = criterion
        self.optimizer = Adam(self.net.parameters(), lr=lr)
        self.scheduler = ReduceLROnPlateau(self.optimizer, mode="min",
                                           patience=3, verbose=True)
        self.accumulation_steps = accumulation_steps // batch_size
        self.phases = ["train", "val"]
        self.num_epochs = num_epochs

        self.dataloaders = {
            phase: get_dataloader(
                imgs_dir = imgs_dir,
                masks_dir = masks_dir,
                path_to_csv = path_to_csv,
                phase = phase,
                batch_size = 8,
                num_workers = 6
            )
            for phase in self.phases
        }
        self.best_loss = float("inf")
        self.losses = {phase: [] for phase in self.phases}
        self.dice_scores = {phase: [] for phase in self.phases}
        self.jaccard_scores = {phase: [] for phase in self.phases}

    def _compute_loss_and_outputs(self,
                                  images: torch.Tensor,
                                  targets: torch.Tensor):
        images = images.to(self.device)
        targets = targets.to(self.device)
        logits = self.net(images)
        loss = self.criterion(logits, targets)
        return loss, logits

    def _do_epoch(self, epoch: int, phase: str):
        print(f"{phase} epoch: {epoch} | time: {time.strftime('%H:%M:%S')}")

        self.net.train() if phase == "train" else self.net.eval()
        meter = Meter()
        dataloader = self.dataloaders[phase]
        total_batches = len(dataloader)
        running_loss = 0.0
        self.optimizer.zero_grad()
        for itr, (images, targets) in enumerate(dataloader):
            loss, logits = self._compute_loss_and_outputs(images, targets)
            loss = loss / self.accumulation_steps
            if phase == "train":
                loss.backward()
                if (itr + 1) % self.accumulation_steps == 0:
                    self.optimizer.step()
                    self.optimizer.zero_grad()
            running_loss += loss.item()
            meter.update(logits.detach().cpu(),
                         targets.detach().cpu()
                        )

        epoch_loss = (running_loss * self.accumulation_steps) / total_batches
        epoch_dice, epoch_iou = meter.get_metrics()

        self.losses[phase].append(epoch_loss)
        self.dice_scores[phase].append(epoch_dice)
        self.jaccard_scores[phase].append(epoch_iou)

        return epoch_loss

    def train(self):
        for epoch in range(self.num_epochs):
            self._do_epoch(epoch, "train")
            with torch.no_grad():
                val_loss = self._do_epoch(epoch, "val")
                self.scheduler.step(val_loss)
            if self.display_plot:
                self._plot_train_history()

            if val_loss < self.best_loss:
                print(f"\n{'#'*20}\nSaved new checkpoint\n{'#'*20}\n")
                self.best_loss = val_loss
                torch.save(self.net.state_dict(), "best_model.pth")
            print()
        self._save_train_history()

    def _plot_train_history(self):
        data = [self.losses, self.dice_scores, self.jaccard_scores]
        colors = ['deepskyblue', "crimson"]
        labels = [
            f"""
            train loss {self.losses['train'][-1]}
            val loss {self.losses['val'][-1]}
            """,

            f"""
            train dice score {self.dice_scores['train'][-1]}
            val dice score {self.dice_scores['val'][-1]}
            """,

            f"""
            train jaccard score {self.jaccard_scores['train'][-1]}
            val jaccard score {self.jaccard_scores['val'][-1]}
            """,
        ]

        clear_output(True)
        with plt.style.context("seaborn-dark-palette"):
            fig, axes = plt.subplots(3, 1, figsize=(8, 10))
            for i, ax in enumerate(axes):
                ax.plot(data[i]['val'], c=colors[0], label="val")
                ax.plot(data[i]['train'], c=colors[-1], label="train")
                ax.set_title(labels[i])
                ax.legend(loc="upper right")

            plt.tight_layout()
            plt.show()

    def load_predtrain_model(self,
                             state_path: str):
        self.net.load_state_dict(torch.load(state_path))
        print("Predtrain model loaded")

    def _save_train_history(self):
        """writing model weights and training logs to files."""
        torch.save(self.net.state_dict(),
                   f"last_epoch_model.pth")

        logs_ = [self.losses, self.dice_scores, self.jaccard_scores]
        log_names_ = ["_loss", "_dice", "_jaccard"]
        logs = [logs_[i][key] for i in list(range(len(logs_)))
                         for key in logs_[i]]
        log_names = [key+log_names_[i]
                     for i in list(range(len(logs_)))
                     for key in logs_[i]
                    ]
        pd.DataFrame(
            dict(zip(log_names, logs))
        ).to_csv("train_log.csv", index=False)

# %%
trainer = Trainer(net=model,
                  criterion=BCEDiceLoss(),
                  lr=8e-5,
                  accumulation_steps=32,
                  batch_size=8,
                  num_epochs=5,
                  imgs_dir = config.path_to_imgs_dir,
                  masks_dir = config.path_to_masks_dir,
                  path_to_csv = config.path_to_csv,)

if config.pretrained_model_path is not None:
    trainer.load_predtrain_model(config.pretrained_model_path)

    # if need - load the logs.
    train_logs = pd.read_csv(config.train_logs_path)
    trainer.losses["train"] =  train_logs.loc[:, "train_loss"].to_list()
    trainer.losses["val"] =  train_logs.loc[:, "val_loss"].to_list()
    trainer.dice_scores["train"] = train_logs.loc[:, "train_dice"].to_list()
    trainer.dice_scores["val"] = train_logs.loc[:, "val_dice"].to_list()
    trainer.jaccard_scores["train"] = train_logs.loc[:, "train_jaccard"].to_list()
    trainer.jaccard_scores["val"] = train_logs.loc[:, "val_jaccard"].to_list()
# Out:
# device: cuda
# Predtrain model loaded

# %%
# %%time
trainer.train()
# Out:
# ####################
# Saved new checkpoint
# ####################
#
#
# CPU times: user 11min 16s, sys: 2min 50s, total: 14min 7s
# Wall time: 14min 29s

# %% [markdown]
# # RESULTS

# %%
val_dataloader = get_dataloader(
    imgs_dir=config.path_to_imgs_dir,
    masks_dir=config.path_to_masks_dir,
    path_to_csv=config.path_to_csv,
    phase = "val",
    batch_size = 8,
    num_workers = 6,
    test_size = 0.2,
)

# %%
# %%time
dice_scores_per_classes, iou_scores_per_classes = compute_scores_per_classes(
    model, val_dataloader, ['lung', 'heart', 'trachea']
    )
# Out:
# CPU times: user 53.2 s, sys: 9.41 s, total: 1min 2s
# Wall time: 1min 34s

# %%
dice_df = pd.DataFrame(dice_scores_per_classes)
dice_df.columns = ['lung dice', 'heart dice', 'trachea dice']

iou_df = pd.DataFrame(iou_scores_per_classes)
iou_df.columns = ['lung jaccard', 'heart jaccard', 'trachea jaccard']
val_metics_df = pd.concat([dice_df, iou_df], axis=1, sort=True)
val_metics_df = val_metics_df.loc[:, ['lung dice', 'lung jaccard',
                                      'heart dice', 'heart jaccard',
                                      'trachea dice', 'trachea jaccard']]
val_metics_df
# Out:
#       lung dice  lung jaccard  heart dice  heart jaccard  trachea dice  \
# 0      0.996163      0.992356    1.000000       1.000000      0.978998
# 1      1.000000      1.000000    1.000000       1.000000      1.000000
# 2      0.952108      0.908594    0.925037       0.860530      1.000000
# 3      0.996221      0.992470    1.000000       1.000000      0.960600
# 4      0.994726      0.989508    0.921728       0.854820      1.000000
# ...         ...           ...         ...            ...           ...
# 3337   0.995919      0.991872    1.000000       1.000000      0.971286
# 3338   0.992145      0.984412    0.926757       0.863512      0.938579
# 3339   1.000000      1.000000    1.000000       1.000000      1.000000
# 3340   0.997368      0.994750    1.000000       1.000000      0.958281
# 3341   0.990545      0.981267    0.990573       0.981321      1.000000
#
#       trachea jaccard
# 0            0.958861
# 1            1.000000
# 2            1.000000
# 3            0.924188
# 4            1.000000
# ...               ...
# 3337         0.944175
# 3338         0.884266
# 3339         1.000000
# 3340         0.919903
# 3341         1.000000
#
# [3342 rows x 6 columns]

# %%
colors = ['#35FCFF', '#FF355A', '#96C503', '#C5035B', '#28B463', '#35FFAF']
palette = sns.color_palette(colors, 6)

fig, ax = plt.subplots(figsize=(12, 6));
sns.barplot(x=val_metics_df.mean().index, y=val_metics_df.mean(), palette=palette, ax=ax);
ax.set_xticklabels(val_metics_df.columns, fontsize=14, rotation=15);
ax.set_title("Dice and Jaccard Coefficients from Validation", fontsize=20)

for idx, p in enumerate(ax.patches):
        percentage = '{:.1f}%'.format(100 * val_metics_df.mean().values[idx])
        x = p.get_x() + p.get_width() / 2 - 0.15
        y = p.get_y() + p.get_height()
        ax.annotate(percentage, (x, y), fontsize=15, fontweight="bold")

fig.savefig("result1.png", format="png",  pad_inches=0.2, transparent=False, bbox_inches='tight')
fig.savefig("result1.svg", format="svg",  pad_inches=0.2, transparent=False, bbox_inches='tight')

# %%
colors = ['#35FCFF', '#FF355A', '#28B463', '#35FFAF', '#96C503', '#C5035B']
palette = sns.color_palette(colors[1::], 3)

fig, ax = plt.subplots(1, 2, figsize=(20, 5))
sns.boxplot(data=dice_df, palette=palette, ax=ax[0])
ax[0].set_ylabel("Dice coefficients for 3342 slices", fontsize=14)
ax[0].set_title("Dice coefficients from Validation", fontsize=20)
ax[0].set_xticklabels(dice_df.columns, fontsize=14)

sns.boxplot(data=iou_df, palette=palette, ax=ax[1])
ax[1].set_ylabel("Jaccard coefficients for 3342 slices", fontsize=14)
ax[1].set_title("Jaccard coefficients from Validation", fontsize=20)
ax[1].set_xticklabels(iou_df.columns, fontsize=14)
plt.tight_layout()

fig.savefig("result2.png", format="png",  pad_inches=0.2, transparent=False, bbox_inches='tight')
fig.savefig("result2.svg", format="svg",  pad_inches=0.2, transparent=False, bbox_inches='tight')

# %% [markdown]
# and train history logs

# %%
train_logs = pd.read_csv(config.train_logs_path)
train_logs.head(5)
# Out:
#    train_loss  val_loss  train_dice  val_dice  train_jaccard  val_jaccard
# 0    0.386394  0.176678    0.697667  0.755589       0.646303     0.717975
# 1    0.144522  0.123104    0.769935  0.786307       0.731782     0.752826
# 2    0.112448  0.093943    0.811846  0.829476       0.775296     0.795960
# 3    0.087972  0.073344    0.838840  0.851835       0.804823     0.819167
# 4    0.073297  0.064866    0.854065  0.861600       0.821115     0.830928

# %%
colors = ['#C042FF', '#03C576FF', '#FF355A', '#03C5BF', '#96C503', '#C5035B']
palettes = [sns.color_palette(colors, 2),
            sns.color_palette(colors, 4),
            sns.color_palette(colors[:2]+colors[-2:] + colors[2:-2], 6)]

fig, ax = plt.subplots(1, 3, figsize=(22, 4))

sns.lineplot(data=train_logs.iloc[:, :2], palette=palettes[0], markers=True, ax=ax[0], linewidth=2.5,)
ax[0].set_title("Loss Function during Model Training", fontsize=14)
ax[0].set_xlabel("Epoch", fontsize=14)

sns.lineplot(data=train_logs.iloc[:, 2:], palette=palettes[1], markers=True, ax=ax[1], linewidth=2.5, legend="full")
ax[1].set_title("Dice and Jaccard Coefficients during Model Training", fontsize=14)
ax[1].set_xlabel("Epoch", fontsize=14)

sns.boxplot(data=val_metics_df.iloc[:,:], palette=palettes[2], ax=ax[2])
ax[2].set_title("Dice and Jaccard Coefficients for each Label from Validation", fontsize=14)
ax[2].set_xticklabels(val_metics_df.columns, fontsize=10, rotation=15)

plt.tight_layout()
fig.savefig("result3.png", format="png",  pad_inches=0.2, transparent=False, bbox_inches='tight')
fig.savefig("result3.svg", format="svg",  pad_inches=0.2, transparent=False, bbox_inches='tight')

# %% [markdown]
# Now let's make a video with overlapped masks for each slice of one id CT

# %%
df = pd.read_csv(config.path_to_csv)
df["Id"] = df['ImageId'].apply(lambda x: x.split("_")[0])

id_ = 'ID00400637202305055099402'
full_scan_example = df.loc[df['Id'] == id_].reset_index(drop=True)
full_scan_example
# Out:
#                                ImageId  \
# 0      ID00400637202305055099402_0.jpg
# 1      ID00400637202305055099402_1.jpg
# 2      ID00400637202305055099402_2.jpg
# 3      ID00400637202305055099402_3.jpg
# 4      ID00400637202305055099402_4.jpg
# ..                                 ...
# 260  ID00400637202305055099402_260.jpg
# 261  ID00400637202305055099402_261.jpg
# 262  ID00400637202305055099402_262.jpg
# 263  ID00400637202305055099402_263.jpg
# 264  ID00400637202305055099402_264.jpg
#
#                                      MaskId                         Id
# 0      ID00400637202305055099402_mask_0.jpg  ID00400637202305055099402
# 1      ID00400637202305055099402_mask_1.jpg  ID00400637202305055099402
# 2      ID00400637202305055099402_mask_2.jpg  ID00400637202305055099402
# 3      ID00400637202305055099402_mask_3.jpg  ID00400637202305055099402
# 4      ID00400637202305055099402_mask_4.jpg  ID00400637202305055099402
# ..                                      ...                        ...
# 260  ID00400637202305055099402_mask_260.jpg  ID00400637202305055099402
# 261  ID00400637202305055099402_mask_261.jpg  ID00400637202305055099402
# 262  ID00400637202305055099402_mask_262.jpg  ID00400637202305055099402
# 263  ID00400637202305055099402_mask_263.jpg  ID00400637202305055099402
# 264  ID00400637202305055099402_mask_264.jpg  ID00400637202305055099402
#
# [265 rows x 3 columns]

# %%
get_color_info()
